# %%
import pandas as pd
shark=pd.read_csv("sharks.csv")

# %%
shark.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# 0        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1        NaN  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3        NaN           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4  2 m shark           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
#
# [5 rows x 24 columns]

# %%
print(shark.dtypes)
print(shark.columns)
shark = shark.drop('Unnamed: 22', axis=1)
shark_clean=shark.drop('Unnamed: 23', axis=1)
cl=shark_clean.isnull().sum()
cl
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %%
import re
#Limpieza columna date
bad_index=list(shark_clean.Date[shark_clean.Date.isnull()].index)
bad_index[0:20]
shark_clean["Date"]
pattern = '\d+-\w+-\d+'

def eli(text):

    sep=re.findall(pattern, text)[0].split('-')
    sep.pop(2)
    return '-'.join(sep)

def det (text):
    r=re.findall(pattern, text)
    return r!=[]

colDate1=[]

for x in colDate:
    if det(x) == True:
        f=eli(x)
        colDate1.append(f)
    else:
        f1=x
        colDate1.append("-")
        
shark_clean["Date"]=colDate1


shark_clean.head()
# Out:
#     Case Number    Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-sep  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-sep  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-sep  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-sep  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-sep  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# 1           N  11h00        NaN  Orlando Sentinel, 9/19/2016
# 2           N  10h43        NaN  Orlando Sentinel, 9/19/2016
# 3           N    NaN        NaN           The Age, 9/18/2016
# 4           N    NaN  2 m shark           The Age, 9/16/2016
#
#                          pdf  \
# 0       2016.09.18.c-NSB.pdf
# 1   2016.09.18.b-Luciano.pdf
# 2       2016.09.18.a-NSB.pdf
# 3  2016.09.17-Angiolella.pdf
# 4  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order
# 0  2016.09.18.c           5993
# 1  2016.09.18.b           5992
# 2  2016.09.18.a           5991
# 3    2016.09.17           5990
# 4    2016.09.15           5989
#
# [5 rows x 22 columns]

# %%
#detectar si hay patron 

e="before 2000 oct 2000 -sep-2000"
def u (text):
    r=re.findall(pattern, e)
    return u!=[]

u(e)
# Out:
# True

# %%
#limpieza de Species
shark_clean["Species "].isnull().sum()
pattern1 = ("\d+|shark|'|,")

def sup (te):
    r=re.sub(pattern1, '', te)
    return r

shark_clean["Species "].fillna('UNKNOWN', inplace=True)
shark_clean["Species "].isnull().sum()
# Out:
# 0

# %%
shark_clean["Species "]=shark_clean["Species "].apply(sup)


shark_clean["Species "]=shark_clean["Species "].str.upper()

def cleaningS (text):
    if "WHIT" in text:
        s = "WHITE"
    elif "TIGE" in text:
        s = "TIGER"
    elif "GRE" in text:
        s = "GREY"
    elif "BLUE" in text:
        s = "BLUE"
    elif "BULL" in text:
        s = "BULL"
    elif "NURSE" in text:
        s = "NURSE"
    elif "MAKO" in text:
        s = "MAKO"
    elif "HAMMER" in text:
        s = "HAMMERHEAD"
    elif "BLACK" in text:
        s = "BLACKTIP"
    elif "WOBBE" in text:
        s = "WOBBEGONG"
    elif "ZAMB" in text:
        s = "ZAMBESI"
    elif "RAGGE" in text:
        s = "RAGGEDTOOTH"
    elif "BRONZE" in text:
        s = "BRONZE WHALER"
    elif "LEMON" in text:
        s = "LEMON"
    elif "SHOVE" in text:
        s = "SHOVELNOSE"
    else:
        s = "UNKNOWN"
    return s

shark_clean["Species "]=shark_clean["Species "].apply(cleaningS)
display(shark_clean["Species "].value_counts())
# Out:
# UNKNOWN          4284
# WHITE             651
# TIGER             282
# BULL              167
# BLACKTIP          109
# GREY               66
# BRONZE WHALER      62
# BLUE               58
# MAKO               54
# NURSE              54
# HAMMERHEAD         47
# WOBBEGONG          44
# RAGGEDTOOTH        44
# ZAMBESI            35
# LEMON              31
# SHOVELNOSE          4
# Name: Species , dtype: int64

# %%
#limpieza col Type


shark_clean.Type=shark_clean.Type.str.replace('Boating' , 'Boat')
set(shark_clean.Type)
shark_clean.Type.value_counts()
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Boat             310
# Sea Disaster     220
# Name: Type, dtype: int64

# %%
#limpieza col Country
shark_clean.Country.head()
display(set(shark_clean.Country))
# Out:
# {' PHILIPPINES',
#  ' TONGA',
#  'ADMIRALTY ISLANDS',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'FALKLAND ISLANDS',
#  'FEDERATED STATES OF MICRONESIA',
#  'FIJI',
#  'FRANCE',
#  'FRENCH POLYNESIA',
#  'Fiji',
#  'GABON',
#  'GEORGIA',
#  'GHANA',
#  'GRAND CAYMAN',
#  'GREECE',
#  'GREENLAND',
#  'GRENADA',
#  'GUAM',
#  'GUATEMALA',
#  'GUINEA',
#  'GULF OF ADEN',
#  'GUYANA',
#  'HAITI',
#  'HONDURAS',
#  'HONG KONG',
#  'ICELAND',
#  'INDIA',
#  'INDIAN OCEAN',
#  'INDIAN OCEAN?',
#  'INDONESIA',
#  'IRAN',
#  'IRAN / IRAQ',
#  'IRAQ',
#  'IRELAND',
#  'ISRAEL',
#  'ITALY',
#  'ITALY / CROATIA',
#  'JAMAICA',
#  'JAPAN',
#  'JAVA',
#  'JOHNSTON ISLAND',
#  'KENYA',
#  'KIRIBATI',
#  'KOREA',
#  'KUWAIT',
#  'LEBANON',
#  'LIBERIA',
#  'LIBYA',
#  'MADAGASCAR',
#  'MALAYSIA',
#  'MALDIVE ISLANDS',
#  'MALTA',
#  'MARSHALL ISLANDS',
#  'MARTINIQUE',
#  'MAURITIUS',
#  'MAYOTTE',
#  'MEDITERRANEAN SEA',
#  'MEDITERRANEAN SEA?',
#  'MEXICO',
#  'MEXICO ',
#  'MICRONESIA',
#  'MID ATLANTIC OCEAN',
#  'MID-PACIFC OCEAN',
#  'MONACO',
#  'MONTENEGRO',
#  'MOZAMBIQUE',
#  'NAMIBIA',
#  'NETHERLANDS ANTILLES',
#  'NEVIS',
#  'NEW BRITAIN',
#  'NEW CALEDONIA',
#  'NEW GUINEA',
#  'NEW ZEALAND',
#  'NICARAGUA',
#  'NICARAGUA ',
#  'NIGERIA',
#  'NORTH ATLANTIC OCEAN',
#  'NORTH ATLANTIC OCEAN ',
#  'NORTH PACIFIC OCEAN',
#  'NORTH SEA',
#  'NORTHERN ARABIAN SEA',
#  'NORTHERN MARIANA ISLANDS',
#  'NORWAY',
#  'OCEAN',
#  'OKINAWA',
#  'PACIFIC OCEAN',
#  'PACIFIC OCEAN ',
#  'PALAU',
#  'PALESTINIAN TERRITORIES',
#  'PANAMA',
#  'PAPUA NEW GUINEA',
#  'PARAGUAY',
#  'PERSIAN GULF',
#  'PHILIPPINES',
#  'PORTUGAL',
#  'PUERTO RICO',
#  'RED SEA',
#  'RED SEA / INDIAN OCEAN',
#  'RED SEA?',
#  'REUNION',
#  'RUSSIA',
#  'SAMOA',
#  'SAN DOMINGO',
#  'SAUDI ARABIA',
#  'SCOTLAND',
#  'SENEGAL',
#  'SEYCHELLES',
#  'SIERRA LEONE',
#  'SINGAPORE',
#  'SLOVENIA',
#  'SOLOMON ISLANDS',
#  'SOLOMON ISLANDS / VANUATU',
#  'SOMALIA',
#  'SOUTH AFRICA',
#  'SOUTH ATLANTIC OCEAN',
#  'SOUTH CHINA SEA',
#  'SOUTH KOREA',
#  'SOUTH PACIFIC OCEAN',
#  'SOUTHWEST PACIFIC OCEAN',
#  'SPAIN',
#  'SRI LANKA',
#  'ST. MAARTIN',
#  'ST. MARTIN',
#  'SUDAN',
#  'SUDAN?',
#  'SWEDEN',
#  'SYRIA',
#  'Seychelles',
#  'Sierra Leone',
#  'St Helena',
#  'TAIWAN',
#  'TANZANIA',
#  'TASMAN SEA',
#  'THAILAND',
#  'THE BALKANS',
#  'TONGA',
#  'TRINIDAD & TOBAGO',
#  'TUNISIA',
#  'TURKEY',
#  'TURKS & CAICOS',
#  'TUVALU',
#  'UNITED ARAB EMIRATES',
#  'UNITED ARAB EMIRATES (UAE)',
#  'UNITED KINGDOM',
#  'URUGUAY',
#  'USA',
#  'VANUATU',
#  'VENEZUELA',
#  'VIETNAM',
#  'WESTERN SAMOA',
#  'YEMEN',
#  'YEMEN ',
#  nan}

# %%
shark_clean.Country.isnull().sum()
shark_clean.Country.fillna('UNKNOWN', inplace=True)
shark_clean.Country.isnull().sum()
# Out:
# 0

# %%
print(shark_clean.Country.value_counts())

pattern2 = ("\s$|^\s|$\?|\(")

def sup1 (te):
    r=re.sub(pattern2, '', te)
    return r

shark_clean.Country=shark_clean.Country.apply(sup1)

pattern3 = ("\s/\s")

def sup2 (te1):
    r=re.sub(pattern3, ' ', te1)
    return r

shark_clean.Country=shark_clean.Country.apply(sup2)

shark_clean.Country=shark_clean.Country.str.replace('MAARTIN' , 'MARTIN').str.replace('?' , '').str.replace('BETWEEN ' , '')
shark_clean.Country=shark_clean.Country.str.replace('COAST OF ' , '')
shark_clean.Country=shark_clean.Country.str.upper().str.replace(" UAE" , '')
set(shark_clean.Country)
# Out:
# USA                             2116
# AUSTRALIA                       1279
# SOUTH AFRICA                     565
# PAPUA NEW GUINEA                 133
# NEW ZEALAND                      125
# BRAZIL                           102
# BAHAMAS                           98
# MEXICO                            81
# ITALY                             71
# FIJI                              62
# PHILIPPINES                       59
# REUNION                           57
# NEW CALEDONIA                     51
# MOZAMBIQUE                        44
# UNKNOWN                           43
# CUBA                              42
# SPAIN                             40
# INDIA                             37
# EGYPT                             36
# CROATIA                           34
# PANAMA                            32
# JAPAN                             32
# IRAN                              29
# SOLOMON ISLANDS                   29
# GREECE                            25
# HONG KONG                         24
# JAMAICA                           23
# FRENCH POLYNESIA                  22
# INDONESIA                         20
# ENGLAND                           19
#                                 ...
# BRITISH ISLES                      1
# NORTH ATLANTIC OCEAN               1
# KOREA                              1
# CYPRUS                             1
# ANTIGUA                            1
# GUYANA                             1
# MID-PACIFC OCEAN                   1
# SLOVENIA                           1
# SYRIA                              1
# SOUTH CHINA SEA                    1
# BAHREIN                            1
# GHANA                              1
# MEDITERRANEAN SEA?                 1
# IRAN / IRAQ                        1
# NORTHERN ARABIAN SEA               1
# RED SEA?                           1
# DIEGO GARCIA                       1
# BAY OF BENGAL                      1
# EQUATORIAL GUINEA / CAMEROON       1
# PARAGUAY                           1
# MARTINIQUE                         1
# BRITISH WEST INDIES                1
# ADMIRALTY ISLANDS                  1
# Sierra Leone                       1
# NORTH SEA                          1
# PALESTINIAN TERRITORIES            1
# Seychelles                         1
# MAYOTTE                            1
# Coast of AFRICA                    1
# GULF OF ADEN                       1
# Name: Country, Length: 204, dtype: int64
# {'ADMIRALTY ISLANDS',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN NICOBAR ISLANDAS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BETWEEN PORTUGAL & INDIA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COAST OF AFRICA',
#  'COLUMBIA',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'EQUATORIAL GUINEA CAMEROON',
#  'FALKLAND ISLANDS',
#  'FEDERATED STATES OF MICRONESIA',
#  'FIJI',
#  'FRANCE',
#  'FRENCH POLYNESIA',
#  'GABON',
#  'GEORGIA',
#  'GHANA',
#  'GRAND CAYMAN',
#  'GREECE',
#  'GREENLAND',
#  'GRENADA',
#  'GUAM',
#  'GUATEMALA',
#  'GUINEA',
#  'GULF OF ADEN',
#  'GUYANA',
#  'HAITI',
#  'HONDURAS',
#  'HONG KONG',
#  'ICELAND',
#  'INDIA',
#  'INDIAN OCEAN',
#  'INDONESIA',
#  'IRAN',
#  'IRAN IRAQ',
#  'IRAQ',
#  'IRELAND',
#  'ISRAEL',
#  'ITALY',
#  'ITALY CROATIA',
#  'JAMAICA',
#  'JAPAN',
#  'JAVA',
#  'JOHNSTON ISLAND',
#  'KENYA',
#  'KIRIBATI',
#  'KOREA',
#  'KUWAIT',
#  'LEBANON',
#  'LIBERIA',
#  'LIBYA',
#  'MADAGASCAR',
#  'MALAYSIA',
#  'MALDIVE ISLANDS',
#  'MALTA',
#  'MARSHALL ISLANDS',
#  'MARTINIQUE',
#  'MAURITIUS',
#  'MAYOTTE',
#  'MEDITERRANEAN SEA',
#  'MEXICO',
#  'MICRONESIA',
#  'MID ATLANTIC OCEAN',
#  'MID-PACIFC OCEAN',
#  'MONACO',
#  'MONTENEGRO',
#  'MOZAMBIQUE',
#  'NAMIBIA',
#  'NETHERLANDS ANTILLES',
#  'NEVIS',
#  'NEW BRITAIN',
#  'NEW CALEDONIA',
#  'NEW GUINEA',
#  'NEW ZEALAND',
#  'NICARAGUA',
#  'NIGERIA',
#  'NORTH ATLANTIC OCEAN',
#  'NORTH PACIFIC OCEAN',
#  'NORTH SEA',
#  'NORTHERN ARABIAN SEA',
#  'NORTHERN MARIANA ISLANDS',
#  'NORWAY',
#  'OCEAN',
#  'OKINAWA',
#  'PACIFIC OCEAN',
#  'PALAU',
#  'PALESTINIAN TERRITORIES',
#  'PANAMA',
#  'PAPUA NEW GUINEA',
#  'PARAGUAY',
#  'PERSIAN GULF',
#  'PHILIPPINES',
#  'PORTUGAL',
#  'PUERTO RICO',
#  'RED SEA',
#  'RED SEA INDIAN OCEAN',
#  'REUNION',
#  'RUSSIA',
#  'SAMOA',
#  'SAN DOMINGO',
#  'SAUDI ARABIA',
#  'SCOTLAND',
#  'SENEGAL',
#  'SEYCHELLES',
#  'SIERRA LEONE',
#  'SINGAPORE',
#  'SLOVENIA',
#  'SOLOMON ISLANDS',
#  'SOLOMON ISLANDS VANUATU',
#  'SOMALIA',
#  'SOUTH AFRICA',
#  'SOUTH ATLANTIC OCEAN',
#  'SOUTH CHINA SEA',
#  'SOUTH KOREA',
#  'SOUTH PACIFIC OCEAN',
#  'SOUTHWEST PACIFIC OCEAN',
#  'SPAIN',
#  'SRI LANKA',
#  'ST HELENA',
#  'ST. MARTIN',
#  'SUDAN',
#  'SWEDEN',
#  'SYRIA',
#  'TAIWAN',
#  'TANZANIA',
#  'TASMAN SEA',
#  'THAILAND',
#  'THE BALKANS',
#  'TONGA',
#  'TRINIDAD & TOBAGO',
#  'TUNISIA',
#  'TURKEY',
#  'TURKS & CAICOS',
#  'TUVALU',
#  'UNITED ARAB EMIRATES',
#  'UNITED ARAB EMIRATES)',
#  'UNITED KINGDOM',
#  'UNKNOWN',
#  'URUGUAY',
#  'USA',
#  'VANUATU',
#  'VENEZUELA',
#  'VIETNAM',
#  'WESTERN SAMOA',
#  'YEMEN'}

# %%
#limpieza col Area
shark_clean.Area.value_counts()
shark_clean.Area.isnull().sum()
shark_clean.Area.fillna('UNKNOWN', inplace=True)


patternA = ('\d+|^\s|\s$|"|\)|,')

def supA (te):
    r=re.sub(patternA, '', te)
    return r
shark_clean.Area=shark_clean.Area.apply(supA)

shark_clean.Area=shark_clean.Area.str.replace('miles ' , '').str.replace('PROVINE' , 'PROVINCE')
shark_clean.Area=shark_clean.Area.str.upper()
display(set(shark_clean.Area))
# Out:
# {'  FROM BERMUDA',
#  ' EAST OF HAWAII',
#  ' EAST OF LUZON',
#  ' EAST OF ST. THOMAS (VIRGIN ISLANDS',
#  ' FROM ANTIGUA',
#  ' FROM LAND',
#  ' KM OFF THE COAST OF IRAN & KM FROM MOUTH OF PERSIAN GULF',
#  ' NM FROM SINGAPORE',
#  ' NM SOUTHEAST OF MANILA',
#  ' NM WEST OF THE CANARY ISLANDS',
#  ' NORTH OF SAN DOMINGO IN THE WEST INDIES',
#  ' OFF THE NORTH COAST',
#  ' OFFSHORE',
#  ' SE OF TARAWA ATOLL',
#  ' SOUTH OF NAPLES',
#  ' SOUTHEAST OF OKINAWA',
#  ' SOUTHEAST OF SRI LANKA',
#  " SOUTHWEST OF O'AHU HAWAII",
#  ' TO  EAST OF WAKE ISLAND',
#  ' TO  OFF TABOGUILLA ISLAND PACIFIC OCEAN',
#  ' WEST OF HAWAII',
#  '(SOUTHWESTERN PACIFIC',
#  '.N .W',
#  '.N-.W',
#  'ABACO ISLANDS',
#  'ABAU SUB DISTRICT CENTRAL PROVINCE',
#  'ABAU SUBDISTRICTCENTRAL PROVINCE',
#  'ADANA PROVINCE',
#  'ADEN',
#  'ADMIRALTY ISLANDS MANUS PROVINCE',
#  'ADRIATIC SEA',
#  'AHIRKAPI COAST',
#  'AICHI PREFECTURE',
#  'AINT-DENIS',
#  'ALABAMA',
#  'ALAGOAS',
#  'ALASKA',
#  'ALICANTE',
#  'ALICANTE PROVINCE',
#  'ALINGLAPLAP ATOLL',
#  'ALPES MARITIME',
#  'ALTAGRACIA PROVINCE',
#  'AMBERGRIS CAYE',
#  'AMIRANTE ISLANDS',
#  'ANATOLIA',
#  'ANCONA PROVINCE',
#  'ANDALUCIA',
#  'ANDAMAN ISLANDS',
#  'ANDIKIRA FOKITHES',
#  'ANDROS ISLANDS',
#  'ANTALYA PROVINCE',
#  'ANTARCTIC OCEAN',
#  'ANTIBES',
#  'ANTOFAGASTA PROVINCE',
#  'ANTSIRANANA PROVINCE',
#  'ANZOATEGUI',
#  'APOLIMA STRAIT',
#  'ARGYLL',
#  'ARGYLLSHIRE',
#  'ARRAN',
#  'ASCENSION BAY',
#  'ATSUMI PENINSULA',
#  'ATTICA',
#  'AULONG ISLAND',
#  'BA RIA-VUNG TAU  PROVINCE',
#  'BAATAN',
#  'BAHIA',
#  'BAIE DE SAINTE-MARIE',
#  'BAJA CALIFORNIA',
#  'BALEARICS',
#  'BALI',
#  'BANAADIR REGION',
#  'BANDAR MAÍSHUR SEA INLET',
#  'BARDESTRAND',
#  'BARLAVENTO ISLANDS',
#  'BASRAH',
#  'BASRAH CITY',
#  'BATANES PROVINE',
#  'BATANGAS PROVINCE',
#  'BAY ISLANDS',
#  'BAY OF BENGAL',
#  'BAY OF BISCAY',
#  'BAY OF CAMPECHE',
#  'BAY OF FUNDY',
#  'BAY OF MAPUTO',
#  'BAY OF MAPUTU',
#  'BAY OF MONACO',
#  'BAYELSA STATE',
#  'BEAUFONDS',
#  'BERNARDINO STRAIT NEAR GULF OF LEYTE',
#  'BERRY ISLANDS',
#  'BETWEEN AUSTRALIA & USA',
#  'BETWEEN BEIRA & MAPUTO',
#  'BETWEEN COMORES & MADAGASCAR',
#  'BETWEEN DR AND PUERTO RICO',
#  'BETWEEN ENGLAND & SOUTH AFRICA',
#  'BETWEEN HASTINGS & FAIRLIGHT SUSSEX',
#  'BETWEEN HAWAII & WAKE ISLAND',
#  'BETWEEN HAWAII AND U.S.A.',
#  'BETWEEN HONIARA & ISABEL ISLAND',
#  'BETWEEN KWAJALEIN ATOLL & JOHNSTON ISLAND',
#  'BETWEEN NEW IRELAND & NEW BRITAIN',
#  'BETWEEN NOUMEA & SYDNEY',
#  'BETWEEN PERTH & COLOMBO',
#  'BETWEEN SOMALIA & YEMEN',
#  'BETWEEN SOUTHAMPTON & CANARY ISLANDS',
#  'BETWEEN TIMOR & DARWIN AUSTRALIA',
#  'BIKINI ATOLL',
#  'BIMINI ISLANDS',
#  'BINH DINH PROVINCE',
#  'BIRD ISLAND',
#  'BISERTA',
#  'BLACK RIVER',
#  'BOA VISTA ISLAND',
#  'BOCAS',
#  'BOCAS DEL TORO',
#  'BOCAS DEL TORO PROVINCE',
#  'BOIS-BLANC',
#  'BONIN ISLANDS',
#  'BORA BORA',
#  'BOUGAINVILLE (NORTH SOLOMONS',
#  'BRINDISI PROVINCE',
#  'BRITISH COLOMBIA',
#  'BRITTANY',
#  'BUENOS AIRES PROVINCE',
#  'BWAGAOIA',
#  'CABO SAN LUCAS',
#  'CAICOS BANK',
#  'CALABRIA',
#  'CALIFORNIA',
#  'CALVADOS ARCHIPELAGO',
#  'CAMAGUEY PROVINCE',
#  'CAMIGUIN ISLAND',
#  'CANAL ZONE',
#  'CANARY ISLANDS',
#  'CAP VERT PENINSULA',
#  'CAP-VERT PENINSULA',
#  'CAPE COAST',
#  'CAPE HAITIEN',
#  'CARABOBO',
#  'CARGADOS CARAJOS SHOALS (ST. BRANDON',
#  'CARIBBEAN COAST',
#  'CARIBBEAN SEA',
#  'CAROLINE ISLANDS',
#  'CARPATHIAN SEA',
#  'CASAMANCE',
#  'CAT CAY',
#  'CATALONIA',
#  'CATALUNYA',
#  'CAVITE PROVINCE LUZON',
#  'CAY SAL BANK',
#  'CENTRAL PHILIPPINES',
#  'CENTRAL PROVINCE',
#  'CENTRAL TUAMOTU',
#  'CHATHAM ISLANDS',
#  'CHATHAM ISLANDS EAST OF NEW  ZEALAND',
#  'CHESHIRE',
#  'CHUNGNAM',
#  'CIENFUEGOS PROVINCE',
#  'CIKOBIA ISLAND (NORTH OF VANUA LEVU',
#  'CLARENDON',
#  'CLEARWATER BAY',
#  'COAST PROVINCE',
#  'COLIMA',
#  'COLON',
#  'COLON PROVINCE',
#  'COLÛN PROVINCE',
#  'CONAKRY REGION',
#  'CONGREVE CHANNEL',
#  'CONNECTICUT',
#  'CONSERVATÛRIA DISTRICT',
#  'COOK ISLANDS',
#  'COOK ISLANS',
#  'COOK STRAIT',
#  'COQUIMBO',
#  'CORFU',
#  'CORFU ISLAND',
#  'CORNWALL',
#  'CORREGIDOR ISLAND',
#  'CORTÈS',
#  'COSTA BLANCA',
#  'CURACAO',
#  'CYCLADES',
#  'CYCLADES ARCHIPELAGO',
#  'CYRENAICA',
#  'C·DIZ',
#  "CÙTE D'AZUR",
#  "CÙTE D'AZUR ",
#  'DAR-ES-SALAAM',
#  'DELAGOA BAY',
#  'DELAWARE',
#  'DELTA',
#  'DEMERARA COUNTY',
#  'DEVON',
#  'DODECANESE ISLANDS',
#  'DORSET',
#  'DUBAI',
#  'DUKE OF YORK ISLANDS',
#  'DÍ…TANG-SALÈ',
#  'EAST COAST',
#  'EAST FLORES',
#  'EAST JAVA',
#  'EAST NEW BRITAIN',
#  'EAST NEW BRITAIN PROVINCE',
#  'EAST OF THE GULF OF AQABA',
#  'EAST SEPIK',
#  'EAST WALL',
#  'EAST YORKSHIRE',
#  'EASTER ROSS',
#  'EASTERN  PROVINCE',
#  'EASTERN CAPE  PROVINCE',
#  'EASTERN CAPE PROVINCE',
#  'EASTERN CAROLINE ISLANDS',
#  'EASTERN CATALONA',
#  'EASTERN PROVINCE',
#  'EDINBURGH',
#  'EHIME PREFECTURE',
#  'ELEUTHERA',
#  'ELQUI PROVINCE',
#  'ENGLISH CHANNEL',
#  'ENIWETOK ATOLL',
#  'ENROUTE FROM SUEZ TO ADEN (YEMEN',
#  'ERONOGO REGION',
#  'ESTUAIRE PROVINCE',
#  'EXUMA ISLANDS',
#  'FERNANDO PO ISLAND',
#  'FIFE',
#  'FLORIDA',
#  'FLORIDA STRAITS',
#  'FOVEAUX STRAIT',
#  'FRENCH SOUTHERN TERRITORIES',
#  'FUJAIRAH EMIRATE',
#  'GALAPAGOS ISLANDS',
#  'GALICA',
#  'GALICIA',
#  'GANGES-BRAHMAPUTRA DELTA',
#  'GAZA',
#  'GENOA  PROVINCE',
#  'GENOA PROVINCE',
#  'GEORGES BANK',
#  'GEORGIA',
#  'GIBRALTAR',
#  'GILBERT ISLANDS',
#  'GOLFO DE VENEZIA',
#  'GOLFO DI GENOVA IN THE LIGURIAN SEA',
#  'GRAN CANARIA',
#  'GRANADA',
#  'GRAND BAHAMA ISLAND',
#  'GRAND BAIE',
#  'GRAND CANARY ISLAND',
#  'GRAND CAYMAN',
#  'GRAND TERRE',
#  'GRAND TURK ISLAND',
#  "GRAND'ANSE",
#  'GREAT EXUMA ISLAND',
#  'GREEN BAY',
#  'GUADALCANAL PROVINCE',
#  'GUAM',
#  'GUANACASTE',
#  'GUANTANAMO PROVINCE',
#  'GUERRERO',
#  'GUERRO',
#  'GUERRRERO',
#  'GUJARAT',
#  'GULF OF LYONS',
#  'GULF OF PANAMA',
#  'GULF OF SUEZ',
#  'GULF OF TADJOURA',
#  'GULF PROVINCE',
#  'GUYAMAS',
#  "HA'API",
#  'HALIFAX',
#  'HAMILTON',
#  'HARARE PROVINCE',
#  'HAVANA PROVINCE',
#  'HAWAII',
#  'HEAD OF THE GULF',
#  'HERZLIYAH',
#  'HO HA WAN MARINE PARK',
#  'HOKKAIDO PREFECTURE',
#  'HOLQUIN PROVINCE',
#  'HONG KONG',
#  'HONIARA',
#  'HOOGLY RIVER',
#  'IBARAKI PREFECTURE',
#  'ILLEGINNI ATOLL',
#  'ILLINOIS',
#  'IMPERIA PROVINCE',
#  'IN CONVOY OB ',
#  'IN THE ENGLISH CHANNEL',
#  'IN THE GULF STREAM',
#  'IN TRANSIT BETWEEN TINIAN AND LEYTE',
#  'INHAMBANE PROVINCE',
#  'INHAMBE PROVINCE',
#  'INNER HEBRIDES',
#  'INNER ISLANDS',
#  'IONIAN SEA',
#  'ISLA PROVEDENCIA',
#  'ISLAND OF KOS',
#  'ISLAND OF ST. THOMAS',
#  'ISLAND OF VOLOS',
#  'ISLE OF MAN',
#  'ISLE OF WIGHT',
#  'ISLES DEL ROSARIO',
#  'ISTANBUL',
#  'ISTRIA',
#  'ISTRIA COUNTY',
#  'IZO ISLANDS',
#  'JAKARTA HARBOUR',
#  'JAVA',
#  'JEJU PROVINCE',
#  'JOHNSTON ATOLL',
#  'JOHOR',
#  'KADAVU',
#  'KADAVU ISLAND GROUP',
#  'KAGAWA PREFECTURE',
#  'KAGOSHIMA PREFECTURE',
#  'KARUN RIVER',
#  'KEDAH',
#  'KENT',
#  'KENTUCKY',
#  'KERALA',
#  'KHUZESTAN PROVINCE',
#  'KH·NH HÚA PROVINCE',
#  'KIKORI RIVER MOUTH',
#  'KINGSTON PARISH',
#  'KOCHI PREFECTURE',
#  'KOWLOON PENINSULA',
#  'KUMAMOTO PREFECTURE',
#  'KURIL ISLANDS IN THE PACIFIC',
#  'KWAJALEIN',
#  'KWAJALEIN ATOLL',
#  'KWAZULU-NATAL',
#  'KWAZULU-NATAL BETWEEN PORT EDWARD AND PORT ST JOHNS',
#  "L' ETANG SALÈ-LES-BAINS",
#  "L'ETANG-SALE",
#  "L'ETANG-SALÈ",
#  'LA LIBERTAD',
#  'LA SALINE-LES-BAINS',
#  'LAGOS',
#  'LAKE NICARAGUA (FRESH WATER',
#  'LAMU ARCHIPELAGO',
#  'LAS PERLAS ARCHIPELAGO',
#  'LAU GROUP',
#  'LAU PROVINCE',
#  'LAUCALA ISLAND',
#  'LE PORT',
#  'LEYTE',
#  'LEYTE ISLAND',
#  'LIGUARIA',
#  'LIGURIA',
#  'LIGURIAN SEA',
#  'LIMPOPO RIVER',
#  'LIMÛN PROVINCE',
#  'LINE ISLANDS',
#  'LOMAIVITI  ISLAND GROUP',
#  'LOMAIVITI PROVINCE',
#  'LOMAIVITI PROVINE',
#  'LOMALOMA LAU',
#  'LOS ROQUES  ISLANDS',
#  'LOS VILOS',
#  'LOUISIADE ARCHIPELAGO',
#  'LOUISIANA',
#  'LOWER SAN JUAN RIVER',
#  'LOYALTY ISLANDS',
#  'LUCY',
#  'LUKOVO',
#  'LUZON',
#  'LUZON ISLAND',
#  'MADANG',
#  'MADANG (WO',
#  'MADANG PROVINCE',
#  'MADEIRA',
#  'MADEIRA ISLANDS',
#  'MAFIA ISLAND',
#  'MAGARITA OR CUBAGUA ISLANDS',
#  'MAGDALENA DEPARTMENT',
#  'MAHARASHTRA',
#  'MAINE',
#  'MAKIRA-ULAWA PROVINCE',
#  'MAKIRA-ULUWA PROVINCE',
#  'MAKORA-ULAWA PROVINCE',
#  'MALAGA',
#  'MALAITA PROVINCE',
#  'MALAMPA PROVINCE',
#  'MALUKU PROVINCE',
#  'MANFREDONIA',
#  'MANGAIA ISLAND',
#  'MANILA',
#  'MANILA BAY',
#  'MANUS ISLAND',
#  'MAPUTO PROVINCE',
#  'MARANH„O',
#  'MARCHES REGION',
#  'MAROVO LAGOON',
#  'MARYLAND',
#  'MASBATE',
#  'MASSACHUSETTS',
#  'MATANZAS PROVINCE (NORTH COAST',
#  'MEDITERRANEAN SEA',
#  'MERCURY ISLANDS',
#  'MERIZO',
#  'MERSIN PROVINCE',
#  'MEXICO / CARIBBEAN SEA',
#  'MIDDLE CAICOS',
#  'MIDWAY ATOLL',
#  'MILNE BAY  PROVINCE',
#  'MILNE BAY PROVINCE',
#  'MINDANAO',
#  'MINDORO',
#  'MINDORO OCCIDENTAL',
#  'MINERVA REEF',
#  'MIRS BAY',
#  'MISAMIS ORIENTAL',
#  'MISSISSIPPI',
#  'MISSOURI',
#  'MIYAKO',
#  'MIYAKO ISLAND',
#  'MOALA ISLAND',
#  'MOLUCCAS',
#  'MOMBASA',
#  'MONTSERRADO',
#  'MOOREA',
#  'MORAY',
#  'MORO GULF',
#  'MOROBE PROVINCE',
#  'MOUNT LEBANON',
#  'MOZAMBIQUE CHANNEL',
#  'MUALA',
#  'MUGLA PROVINCE',
#  'MUHAFAZAT HADRAMAWT',
#  'MUNXAR REEF',
#  'M·LAGA',
#  'N W',
#  'NAGASAKI PREFECTURE',
#  'NAMONUITO ATOLL',
#  'NAPLES PROVINCE',
#  'NEAR BOUGAINVILLE (NORTH SOLOMONS',
#  'NEAR DAKAR CAP VERT PENINSULA',
#  'NEAR PUNTARENAS',
#  'NEAR THE ANDAMAN & NICOBAR ISLANDS',
#  'NEAR THE FIJI ISLANDS',
#  'NEGROS',
#  'NEW BRITAIN',
#  'NEW BRITAIN BISMARCK ARCHIPELAGO',
#  'NEW BRUNSWICK',
#  'NEW GEORGIA',
#  'NEW IRELAND',
#  'NEW IRELAND BISMARCK ARCHIPELAGO',
#  'NEW IRELAND PROVINCE',
#  'NEW IRELAND PROVINCE BISMARCK ARCHIPELAGO',
#  'NEW JERSEY',
#  'NEW MEXICO',
#  'NEW PROVIDENCE ISLAND',
#  'NEW SOUTH WALES',
#  'NEW TERRITORIES',
#  'NEW YORK',
#  'NEWFOUNDLAND',
#  'NICE & MARSEILLES',
#  'NICOYA PENINSULA',
#  'NIUA',
#  'NORFOLK',
#  'NORFOLK ISLAND',
#  'NORTH & SOUTH CAROLINA',
#  'NORTH CAROLINA',
#  'NORTH CHINA',
#  'NORTH DEVON',
#  'NORTH ISLAND',
#  'NORTH OF PERNAMBUCO BRAZIL',
#  'NORTH PACIFIC COAST',
#  'NORTH PALAWAN',
#  'NORTH PROVINCE',
#  'NORTH REGION',
#  'NORTH SUMATRA',
#  'NORTHERN (ORO PROVINCE',
#  'NORTHERN BAHAMAS',
#  'NORTHERN DISTRICT',
#  'NORTHERN JAVA',
#  'NORTHERN PELOPONNESE',
#  'NORTHERN PROVINCE',
#  'NORTHERN TAIWAN',
#  'NORTHERN TERRITORY',
#  'NORTHLANDS',
#  'NORTHWEST ITALY',
#  'NORTHWEST OF PAPUA NEW GUINEA',
#  'NORTHWEST OF VITI LEVU',
#  'NOVA SCOTIA',
#  'NUEVA ESPARTA',
#  "NUKU'ALOFA",
#  'OAXACA',
#  'OFF CAPE HAITIEN',
#  'OFF COAST OF ECUADOR',
#  'OFF COAST OF WEST AFRICA',
#  'OFF GREEN ISLAND',
#  'OFF IRELAND',
#  'OFF LIBYA',
#  'OFF SAMAR ISLAND IN THE GULF OF LEYTE',
#  'OFF SOUTH AMERICAN COAST',
#  'OFF THE COAST OF SOUTH AMERICA',
#  'OFF THE COAST OF WEST AFRICA',
#  'OFF THE COROMANDEL PENINSULA NORTH ISLAND',
#  'OFF THE WESTERN COAST OF PENINSULAR MALAYSIA',
#  'OFF THESSALY',
#  'OFF VANUA LEVU',
#  'OKAYAMA PREFECTURE',
#  'OKINAWA PREFECTURE',
#  'ON THE KOWLOON PENISULA SOUTH OF SAI KUNG',
#  'OPEN SEA',
#  'OREGON',
#  'ORISSA',
#  'OSLO FJORD',
#  'OUT ISLANDS',
#  'PACIFIC COAST',
#  'PACIFIC OCEAN',
#  'PAGASITIKOS GULF',
#  'PAGET',
#  'PALAWAN',
#  'PALMYRA ATOLL',
#  'PANAMA',
#  'PANAMA BAY (PACIFIC OCEAN',
#  'PANAMA CITY',
#  'PARAIBA',
#  'PEARL ISLANDS',
#  'PENNSYLVANIA',
#  'PERNAMBUCO',
#  'PETER THE GREAT BAY KHASAN PRIMORSKY KRAI (FAR EAST',
#  'PHANG NGA PROVINCE',
#  'PHOENIX ISLANDS',
#  'PHUKET',
#  'PINAS BAY',
#  'PIRAEUS',
#  'PORT LOUIS PROVINCE',
#  'PORT SHELTER',
#  'PORTO SEGURO',
#  'PRASLIN',
#  'PRIMORJE-GORSKI KOTAR COUNTY',
#  'PRIMORSKY KRAI',
#  'PROVENCE',
#  'PROVIDENCIALES',
#  'PUERTO RICO',
#  'PUNTARENAS PROVINCE',
#  'QUEAON',
#  'QUEENSLAND',
#  'QUEZON',
#  'QUINTANA ROO',
#  'RALIK ARCHIPELAGO',
#  'RALIK CHAIN',
#  'RANGIROA',
#  'RANGOON',
#  'RATAK',
#  'RAYONG PROVINCE',
#  'RED SEA',
#  'RED SEA STATE',
#  'REGGIO CALABRIA PROVINCE',
#  'RHODE ISLAND',
#  'RIAU PROVINCE',
#  'RIGO SUBDISTRICT',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DE NORTE',
#  'RIO GRANDE DO SUL',
#  'RIO SAN JUAN',
#  'RIVERS STATE',
#  'ROCHA',
#  'RODRIGUES',
#  'ROMBION PROVINCE',
#  'ROMBLON PROVINCE',
#  'RONCADOR BANK',
#  'RYUKYU',
#  'S / E',
#  'S ?E',
#  'SAGO PREFECTURE',
#  'SAINT GILLES',
#  'SAINT LEU',
#  'SAINT-BENOIT',
#  'SAINT-BENOÓT',
#  'SAINT-DENIS',
#  'SAINT-GILLES',
#  'SAINT-GILLES-LES-BAINS',
#  'SAINT-JOSEPH',
#  'SAINT-LEU',
#  'SAINT-LOUIS',
#  'SAINT-PAUL',
#  'SAINT-PHILIPPE',
#  'SAINT-PIERRE',
#  'SAINTE-MARIE',
#  'SAINTE-SUZANNE',
#  'SAIPAN',
#  'SALERNO',
#  'SALERNO PROVINCE',
#  'SALINAS BAY',
#  'SAMAN· PROVINCE',
#  'SAN ANDRÈS ARCHIPELAGO',
#  'SAN BLAS',
#  'SAN BLAS COAST',
#  'SAN BLAS ISLANDS',
#  'SAN CARLOS',
#  'SANDAUN PROVINCE',
#  'SANMA PROVINCE',
#  'SANTA CATARINA STATE',
#  'SANTA CRUZ ISLAND',
#  'SANTA ELENA',
#  'SANTA ISABEL PROVINCE',
#  'SANTIAGO DE CUBA PROVINCE',
#  'SANTIAGO ISLAND',
#  'SANTO DOMINGO',
#  'SANTS-MONTJIC',
#  'SARDINIA',
#  'SAVONA',
#  'SEA OF JAPAN',
#  'SFAX',
#  'SHANGHAI',
#  'SHARON',
#  'SHAT-AL-ARAB RIVER',
#  'SHATT-AL-ARAB RIVER',
#  'SHATT-EL-ARAB RIVER',
#  'SHEFA PROVINCE',
#  'SICILY',
#  'SIMPSON BAY',
#  'SINAI PENINSULA',
#  'SINALOA',
#  'SINGAPORE HARBOR',
#  'SKAGERRAK ARM OF THE NORTH SEA',
#  'SLOVENIA',
#  'SOCIETY ISLANDS',
#  'SOCOTRA ISLANDS',
#  'SOMEWHERE BETWEEN PHILADELPHIA AND HIOGO JAPAN',
#  'SOUTH ATLANTIC OCEAN',
#  'SOUTH AUSTRALIA',
#  'SOUTH CAROLINA',
#  "SOUTH CH'UNGCH'ONG PROVINCE",
#  'SOUTH CHINA SEA  FROM HONG KONG',
#  'SOUTH CHUNGCHEONG PROVINCE',
#  'SOUTH COAST EAST NEW BRITAIN',
#  'SOUTH DEVON',
#  'SOUTH ISLAND',
#  'SOUTH ISLAND NEAR KARITANE NORTH OF DUNEDIN',
#  'SOUTH ISLAND?',
#  'SOUTH KOREA',
#  'SOUTH OF THE EQUATOR',
#  'SOUTH PACIFIC OCEAN',
#  'SOUTH PROVINCE',
#  'SOUTH SHORE',
#  'SOUTH SINAI GULF OF AQABA',
#  'SOUTH SINAI PENINSULA',
#  'SOUTHERN CYPRUS',
#  'SOUTHERN DISTRICT',
#  'SOUTHERN JAPAN',
#  'SOUTHERN PROVINCE',
#  'SOUTHERN THAILAND',
#  'SOUTHLAND',
#  'SOUTHWEST COAST',
#  'SPLIT-DALMATIA COUNT',
#  'SPLIT-DALMATIA COUNTY',
#  "ST JOHN'S",
#  'ST MICHAEL PARISH',
#  'ST. ANDREW PARISH',
#  'ST. ANNE',
#  'ST. CATHERINE',
#  'ST. GEORGES',
#  'ST. JOHNS REEF',
#  "ST. MARY'S PARISH",
#  'ST. THOMAS BAY',
#  'STRAIT OF MALACCA',
#  'STRAIT OF MESSINA',
#  'SUCRE',
#  'SUEZ',
#  'SURIGAO DEL NORTE',
#  'SUSSEX',
#  'SYRACUSE',
#  'TABUK PROVINCE',
#  'TAFEA PROVINCE',
#  'TAIPEI HSIEN',
#  'TAITUNG',
#  'TAMAULIPAS',
#  'TAMIL NADU',
#  'TAMILNADU',
#  'TARANTO',
#  'TARANTO PROVINCE',
#  'TASMANIA',
#  'TAVENUI',
#  'TAVEUNI',
#  'TEL AVIV',
#  'TELYAKOVSKY BAY KHASAN  PRIMORSKY KRAI (FAR EAST',
#  'TERAMO',
#  'TERRITORY OF COCOS (KEELING ISLANDS',
#  'TEXAS',
#  'THESSALY',
#  'TIBURON PENINSULA',
#  'TOAMASINA PROVINCE',
#  'TOKYO PREFECTURE',
#  'TONGAPATU GROUP',
#  'TONGATAPU',
#  'TORRES STRAIT',
#  'TRANSVAAL',
#  'TRELAWNEY PROVINCE',
#  'TRIESTE',
#  'TRINIDAD',
#  'TROIS-BASSINS',
#  'TUAMOTOS',
#  'TUAMOTUS',
#  'TURTLE BOGUE',
#  'TUSCANY',
#  'TUTUILA ISLAND',
#  'TYRRENIAN SEA',
#  'TYRRHENIAN SEA',
#  'UMM AL QAYWAYAN PROVINCE',
#  'UNITED ARAB EMIRATES',
#  'UNKNOWN',
#  'UNKNOWN TREATED AT WICK SCOTLAND',
#  'UPOLU ISLAND',
#  'US VIRGIN ISLANDS',
#  'VALENCIA',
#  'VALPARISO PROVINCE',
#  'VANCOUVER',
#  'VANUA LEVU',
#  "VAVA'U",
#  'VAVAÍU',
#  'VENICE PROVINCE',
#  'VERA CRUZ',
#  'VERACRUZ',
#  'VICTORIA',
#  'VILLA CLARA PROVINCE',
#  'VIRGINIA',
#  'VISCAYAN SEA',
#  'VITA LEVU',
#  'VITI LEVU',
#  'VITI LEVU GROUP',
#  'VITI LEVU ISLAND',
#  'VITU LEVU',
#  'WAKAYA ISLAND',
#  'WAKAYAMA PREFECTURE',
#  'WAKE ISLAND',
#  'WAKE ISLAND (ENENKIO',
#  'WALKERS CAY',
#  'WALLIS AND FUTUNA',
#  'WASHINGTON',
#  'WEST AFRICA',
#  'WEST BENGAL',
#  'WEST COAST',
#  'WEST END',
#  'WEST NEW BRITAIN PROVINCE',
#  'WEST OF CEYLON (SRI  LANKA',
#  'WESTERN AREA',
#  'WESTERN AUSTRALIA',
#  'WESTERN BANKS',
#  'WESTERN CAPE PROVINCE',
#  'WESTERN CAROLINE ISLANDS',
#  'WESTERN CAROLINE ISLANDS (NORTH PACIFIC OCEAN',
#  'WESTERN DISTRICT',
#  'WESTERN LUZON ISLAND',
#  'WESTERN PAPUAN GULF',
#  'WESTERN PROVINCE',
#  'WESTERN VISCAYAS',
#  'WESTMORELAND PARISH',
#  'WOODLARK ISLANDS',
#  'WORCESTERSHIRE',
#  'YASAWA ISLANDS',
#  'YSABEL ISLAND',
#  'YUCATAN CHANNEL',
#  'ZADAR COUNTY',
#  'ZAMBESI RIVER',
#  'ZAMBOANGA DEL SUR PROVINCE',
#  "∫ : ∫'",
#  '∫N ∫E',
#  '∫S ∫E'}

# %%
#limpieza col Location
shark_clean.Location.isnull().sum()
shark_clean.Location.fillna('UNKNOWN', inplace=True)
patternL = ('\s$|^\s|"|\)|,')

def supL (te):
    r=re.sub(patternL, '', te)
    return r
shark_clean.Location=shark_clean.Location.apply(supL)

display(set(shark_clean.Location))
# Out:
# {'Tupuselei Village about 40 miles east of Port Moresby',
#  'Nakalele Point Maui',
#  'the pearling beds',
#  'Off Bilisan Point Hinatuarn Island',
#  'Hobson Bay',
#  'Tamavua River',
#  'Roku Point',
#  'Body recovered at Goiana',
#  'Isipingo',
#  'Vityaz',
#  'Shoalhaven',
#  'Fort Lauderdale Broward County',
#  'IlhÈus',
#  'St. Georgeís Channel',
#  'Mpande',
#  'Praia del Chifre Olinda',
#  'Manasota Beach Sarasota County',
#  'Refugio State Beach Santa Barbara County',
#  '5 km from Gordonís Bay False Bay',
#  'Three Mile Reef off Lizard Island 50 miles north of Cooktown',
#  'Hadrianís (Haidana? Island near Port Moresby',
#  "Keawanui Kamalo Moloka'i",
#  'Hutchinson Island Martin County',
#  'Petite-Ile',
#  'Boa Viagem Beach Recife',
#  'Tuvuca Isalnd',
#  'Dolphin Bay Innes National Park',
#  'South Coast',
#  'Bakers Bay',
#  'Huguenot Park',
#  'Troncones Beach',
#  'Yeppoon',
#  'Aldinga Beach',
#  'Waiehu Maui',
#  'Pine Island Corolla Currituck County',
#  'Shark caught in Indonesia offloaded to trawler that docked at Samut Prakan 20 miles south of Bangkok Thailand',
#  'Indian Rocks Beach Clearwater Pinellas County',
#  'Cudgen Creek',
#  "Honomuni Moloka'i",
#  '68 miles east of Wallis Island',
#  'Phillip Island',
#  'Paramatta River',
#  'Veracruz',
#  'Xefina Island',
#  'Marino',
#  'Cowes',
#  'Off Fleetwood',
#  'Steamship bound from Cape Town to Philadelphia',
#  'Santa Monica Los Angeles County',
#  'Santa Maria Bar',
#  'Walton Rocks St Lucie County',
#  'Mangrove Cay',
#  "Waialua Bay O'ahu",
#  'Bribie Passage Caloundra',
#  'Florida Keys',
#  'Marineland Aquarium Manley Sydney',
#  'Palm Beach North 5 miles north of Burleigh Heads Brisbane',
#  'Near Mabuiag Island',
#  'Off Bribie Heads',
#  'Wailea Beach Maui',
#  'Carlin Park Jupiter Palm Beach County',
#  'Coral Gardens Reef 6 miles SSE of Chicoteague Inlet',
#  "Five Mile Beach I'le Ouen",
#  'False Cape',
#  'Carolina Beach',
#  'George Town Cove',
#  'Cooks Hill Newcastle',
#  'Seaside',
#  'Leigh',
#  'Montauk',
#  'Strandfontein',
#  'Bonita Springs Lee County',
#  'Neskowin Tillamook County',
#  'Great Mercury Island',
#  'Micklers Landing St. Johns County',
#  '10 miles off Redondo Beach Los Angeles County',
#  "Follett's Island Brazoria County",
#  'Varazze',
#  'Playalinda Beach Canaveral National Seashore Brevard County',
#  'Hinchinbrook Channel Queensland',
#  'Delray Beach Palm Beach County',
#  'Little Island near Hillarys',
#  'Cape San Blas Gulf County',
#  'Samoa Beach Humboldt County',
#  'Gulf of Mexico',
#  'Jacobs Bay Reef Saldanha Bay',
#  'Canova Beach Brevard County',
#  'Broken Head',
#  'Burleigh Lake on the Gold Coast',
#  'Moö?eni?ka Draga',
#  'African Reef off Geraldton',
#  'Freetown',
#  'Ponte Vedra Beach St Johns County',
#  'near Trikerion Island',
#  'Florida Straits',
#  'Galveston Island',
#  "Kealia Beach Kaua'i",
#  'Woy Woy on the Brisbane Waters',
#  'Elphinstone Reef',
#  'Kihei Maui',
#  'Sanibel Island Lee County',
#  'Bribie Island',
#  '125 nm north of Aruba',
#  'Ocracoke Inlet',
#  '34th Avenue North Myrtle Beach Horry County',
#  'North Coast Guadalcanal Island',
#  'Bay of Bweedro OuvÈa',
#  'Salmon Creek Sonoma County',
#  'Alligator Head La Jolla San Diego County',
#  'Tarrafal',
#  'Cape Town',
#  'Jurien Bay',
#  'Nova Vicosa',
#  'Brest',
#  '10 miles offshore from Sea Isle City Cape May County',
#  "Ha'ano Island",
#  'Widenham',
#  'Olifantbos Point',
#  'Kicha Island',
#  'Makaha Surf Beach',
#  'Bulu Talasea',
#  'Bolsa Chica State Park Orange County',
#  'Playas de Tijuana',
#  'Darwin',
#  'Port Jervis',
#  'Municipal Beach Boyton Beach Palm Beach County',
#  'Oakura Beach Taranaki',
#  'Coffee Bay',
#  'Bimat Bogia',
#  'Near the Abrolhos Archipelago',
#  'Stilbaai',
#  'SeaWorld Theme Park',
#  'Double Breasted Cays',
#  'Carradale Bay Kintyre Peninsula',
#  'Kalama Park Maui',
#  'Marion Bay',
#  'Totoya ',
#  'Lampedusa Island',
#  'Victoria Bay',
#  'Buck Island',
#  'Floreat Beach',
#  "Park Beach Coff's Harbour",
#  'Wurtulla',
#  'Rhio Strait',
#  'Albenga',
#  'Tahuna Beach Nelson',
#  "Ned's Beach Lord Howe Island",
#  'Murwillumbah Tweed River',
#  'Patapsco River',
#  '1 mile ESE of Navesink Monmouth County',
#  'Near Port Moresby',
#  'Outside Vera Cruz Harbor',
#  'Malake Island Ra Province',
#  'Off Blacksmith Beach',
#  'San Benedetto',
#  'West Breakwater Monrovia / Freeport',
#  'Off Eva Island 20 miles from Cardwell',
#  'St. Crispin Reef',
#  'Thirroul',
#  'Yellow Sands Point',
#  'Boyup Brook',
#  'Manomet Point Plymouth Plymouth County',
#  "Niuafo'ou Island",
#  'Smyrna Dunes Park New Smyrna Beach Volusia County',
#  'Surfside Beach Horry  County',
#  'Fitzroy River near Rockhampton',
#  '20 m from shore at Strand',
#  'Fort Moultrie',
#  'Smokvina Bay Vis Island',
#  'Hanalei Bay Kauai',
#  "Noreiga's Maui",
#  'Off Cape Hatteraa',
#  'Beru',
#  'Near the wreck of the Kakapo off Noordhoek Beach',
#  'Egmont Key Hillsborough County',
#  'Pensacola Escambia County',
#  'River Sierra Leone 35 miles  upriver from Freetown',
#  'Maroochydore',
#  'Surabaya',
#  "Near Fisherman's Island",
#  'La Libertad',
#  'Oahu',
#  'Mayport Naval Station Jacksonville Duval Country',
#  '2 miles off Santa Catalina Island',
#  'Melbourne',
#  'Sarcelle Isle of Pines',
#  '2 miles east of Dania Beach Broward County',
#  'Lake Macquarie',
#  "Kylie's Beach Diamond Head",
#  "Lanaikea O'ahu",
#  'Manly Marineland Sydney',
#  'Apia Harbour',
#  'Santa Cruz Santa Cruz County',
#  'Atlantiic Beach Duval County',
#  '300 yards west of mouth of the Chagres River',
#  'Weymouth',
#  'Sarcelle',
#  "Bateman's Bay",
#  'Mereweather Beach',
#  'Bethune Beach Volusia County',
#  'Scotts Point Beach',
#  'Floridana Beach Brevard County',
#  'Garden City',
#  'Just below Roseville Bridge opposite Killarney picnic reserve Middle Harbor Sydney',
#  'Dando/Kaeui Island',
#  'Fort Pierce St. Lucie County',
#  'Kwajalein Atoll',
#  'Honeysuckle Point Eden',
#  'Spessard Holland Park Melbourne Beach Brevard County',
#  'Off Mondello Lighthouse',
#  "Watson Taylor's Lake 25 miles south of Port Macquarie",
#  'Port River Adelaide',
#  'Mona Vale',
#  'Korem Finschhafen',
#  'Near Suva',
#  'Pigeon Point San Mateo County',
#  'Cockatoo Island Sydney',
#  'Scottís Point Redcliffe Peninsula',
#  'South of Neptune Beach Duval County',
#  'Inshore side of reef near Madang',
#  'Bullcock Beach',
#  'Fort Lauderdale',
#  'Off 21st Avenue Isle of Palms Charleston County',
#  'Big Island off Kona Village Resort North Kona',
#  'Ulua Beach Maui',
#  'Reef on seaward side of Geyser Island',
#  'Bavaro Beach Punta Cana',
#  'Seven Mile Beach Byron Bay',
#  'Off Inhaca Island',
#  'Sandon',
#  "North of main swimming area in Waterman's Bay Beach Perth",
#  'Nagahama-cho 40 km southwest of Matsuyama',
#  "Pearl Harbor O'ahu",
#  'Stil Bay',
#  'Jimmys Beach Port Stephens',
#  'Su?uraj Hvar Island',
#  'Malakula (Malakula Island',
#  'Calibogue Sound',
#  'Monterey Monterey County',
#  'Middle Harbour Sydney',
#  'Kanaha Beach Maui',
#  'Carrara Nerang River',
#  'Normandy Beach Hutchinson Island  St. Lucie County',
#  'Libertad San Onofre',
#  'Millerís Point',
#  'Kissing Point Camp Townsville',
#  'Portlock Oahu',
#  'Lachan Island Mercury Passage',
#  '30 nautical miles offshore',
#  'St. Leu',
#  'Pacific Grove Monterey Bay Monterey County',
#  'Waikanae Beach Gisborne',
#  'Marine Parade Napier Hawke Bay',
#  'Piedade Beach',
#  'Pensacola  Beach Escambia County',
#  'Key Biscayne',
#  'Gnaraloo',
#  'near Schouten Island',
#  'Kerpuna',
#  'Smokey Cape',
#  'St. Clair Beach Dunedin',
#  'Daytona Beach Volusia County',
#  'Curlew Island Breton Sound',
#  'Collendina Beach east of Ocean Grove',
#  'Off Mkhambati',
#  'Dover Heights Sydney',
#  'Bound from New York to London in ballast',
#  'Island Rock',
#  'Ziguinchor',
#  'Bellambi Reef',
#  'North Topsail Beach Onslow  County',
#  'Virginia Aquarium & Marine Science Center Virginia Beach',
#  'Nasigilatu (Near Malasanga Finschhafen in the Huon Gulf',
#  'Cherie Down Park Brevard County',
#  'Woodmanís Point',
#  'Altona Melbourne',
#  'Palm Beach County',
#  'Galliera dock Genoa',
#  'Shelter Cove Humboldt County',
#  'Miall Island',
#  'Manayaweli Cove Trincomalee',
#  'Tahunanui Beach',
#  'Dunedin',
#  'Umtentweni',
#  'Monterey Bay Monterey County',
#  'West Balmain Sydney',
#  'Santa Maria Peninsula',
#  'Table Beach Brevard County',
#  "Hobson's Bay",
#  'Nailou Village Tunuloa Natewa Bay',
#  'Nonouti',
#  'Haulover Inlet Dade County',
#  'San Stefano',
#  'Pawleyís Island Georgetown County',
#  "Turners' Beach",
#  'Davis Shore east of Beaufor Carteret Countyt',
#  'Limantour Beach Point Reyes National Seashore',
#  'Off Point Mugu Ventura County',
#  'Hatkolah Ghat',
#  'At Panihattu Barrackpore Dackhineshwar Barahonagore Kashipur & Chitpur down to Baug Bazar ghats',
#  'Hoogly River Calcutta',
#  "Sprizze Isola d'Elba",
#  'Hammocks Beach State Park Bear Island Onslow County',
#  '100 miles offshore',
#  'Piedade Beach Recife',
#  'Mabini',
#  'Waitpinga Beach near Victor Harbor Encounter Bay',
#  'Marinella Sarzana La Spezia',
#  'Terrigal Beach',
#  'Isle of Wight',
#  'Huguenot Memorial Park Duval County',
#  'Cronulla near Sydney',
#  "Cooper's Point",
#  'Providence',
#  'Southport',
#  'Cape Elizabeth',
#  'Seaport Brevard County',
#  '10 miles off Nambucca Heads  onboard trawler',
#  'Pigeon Island',
#  'Playa Villa del Mar',
#  'Volusia County ',
#  'Chester River',
#  'Fort Mills',
#  'Off Lake Worth Palm Beach County',
#  'Darwin Harbour',
#  "M'Buke south of Manus Island",
#  'Second Beach Port St Johns',
#  'Crowdy Head',
#  'Off Legendre Island',
#  'New Brighton',
#  'Tiaroye near Dakar Cap Vert Peninsula',
#  'Ashdod',
#  'Perdido Key near the Florida Panhandle Escambia County',
#  'Off Crystal River Citrus County',
#  'Off Snipe Point Florida Keys Monroe County',
#  'Mutton Bird Island Albany',
#  'Palm Beach Shores Riviera Beach Singer Island Palm Beach County',
#  'Momote Manus Island',
#  'Flinders Cay',
#  'Umzimkulu',
#  'Bird Island Algoa Bay',
#  'Ile de Loss',
#  'Landing Place',
#  'Pennington Bay Kangaroo Island',
#  'Satellite  Beach Brevard County',
#  'Yoff Island',
#  'Onboard swordfish trawler',
#  "East Moloka'i",
#  'American Shoals off Key West',
#  "Ha'ena Kaua'i",
#  'Huntington Beach Orange County',
#  'Port Elizabeth',
#  'Hallidays Point',
#  'Jeju Island',
#  "Nimitz Beach Barbers Point O'ahu",
#  'Port Lavaca Calhoun County',
#  'Oketee River Jasper County',
#  'North Beach Hutchinson Island St. Lucie County',
#  'Rapindik Beach Rabaul',
#  'El Cocal Beach',
#  'Somewhere between Hatteras and Beaufort',
#  'Nahaduga Inhambane Bay',
#  'Snapper Point',
#  "Makaha O'ahu",
#  'Mito',
#  'Cape Canaveral',
#  'Xefina Island Bay of Maputo',
#  'Hooghley River near Budge-Budge',
#  'Off Singer Island Palm Beach County',
#  'Budva',
#  'Ensenada de la Coronilla',
#  'Near Barrow Point Queensland',
#  'Off Diable Island',
#  'Oceanic Pier Wrightsville Beach New Hanover County',
#  'Okaloosa Island',
#  'Carlin Park Jupiter Inlet',
#  'Bayshore Garden Sarasota Bay Sarasota County',
#  'Sohano Island Buka Passage',
#  'Makahuena Point Kauai',
#  'Southern end',
#  "Pa'uwela Maui",
#  'Off West End',
#  'Lifou',
#  '1 km off the mouth of Marsa Bereika north of Ras Mohammed',
#  'Shelly Point',
#  '50 km east of Townsville',
#  "Ho'okipa Beach Pa'ia Maui",
#  "Kahala O'ahu",
#  'Orava (Aravo Islet  near Kieta.',
#  'Off Cape Eleuthera',
#  'Near Cairns',
#  'St. Petersburg Pinellas County',
#  'Horseshoe Bay',
#  '750 miles off the African coast',
#  'Fort Pierce Inlet State Park St Lucie County',
#  'Caves near Kogel Bay',
#  'Kendec',
#  'Nobbys Beach',
#  'First Beach Forster',
#  'Onboard the fishing vessel Chin Sheng Fa 13 ',
#  'Between Wrightsville Beach & Carolina Beach New Hanover County',
#  'Elephant Rock Currumbin near Southport',
#  'Hollywood Broward County',
#  'Caves Beach',
#  "Waimea Bay O'ahu",
#  'North Pier Durban',
#  'Matanzas',
#  'New Smyrna Beach  Volusia County',
#  'Daedalus Reef†',
#  'El Falito near Puerto Cabello',
#  'Surfside Beach Brazoria County',
#  'Midway Island Northwestern Hawaiian Islands',
#  'Mzimvubu River mouth',
#  'Winyah Bay',
#  'Moreton Bay NE of Brisbane',
#  'Las Palmas',
#  "I'le Ouen",
#  'Redcliff Cobourg Peninsula',
#  'Miami Miami-Dade County',
#  'Cagayan de Oro',
#  'Miramar Beach 46 km south of Mar de Plata Buenos Aires',
#  'Miramar Beach Tampico',
#  'Manila Bay',
#  'Off Poison Creek Cape Arid',
#  'Ravine Mula',
#  "Surfers' Corner Muizenberg False Bay",
#  'City Beach Perth',
#  'North Cronulla Beach',
#  'Windmill Beach',
#  'Strait of Messina',
#  'Surf Beach Batemans Bay',
#  '1.5 km north of Igata-cho 60 km south of Matsyama',
#  'Off Cartagena',
#  'Off Jaimanitas Yacht Club Havana',
#  'Nimitz State Beach Oahu',
#  'Ramin near Ahvaz',
#  'Playa Brava Turtle Bay',
#  'Suva Harbor',
#  'North Beach St. Lucie County',
#  'Japanese fishing boat Taihei Maru No.10',
#  'Wilkes Islet Lagoon (Pacific Ocean north of the Marshall Islands',
#  'Kanahena Cove',
#  'North Salmon Creek Beach Sonoma County',
#  'Halewia Oahu',
#  'Salmon Creek Beach Sonoma County',
#  "Port St. John's",
#  'Parismina',
#  "Dobu Passage  D'Entrecasteaux Islands (between Normanby & Fergusson Islands",
#  '500 nautical miles southwest of Johnston Island',
#  'Descano Point',
#  'Isle of Palms Charleston County',
#  'Silverstrand Beach near Hung Hau',
#  'Phang nga Island',
#  'Robberg Point',
#  'Elliston Eyre Peninsula',
#  '6th Avenue North Myrtle Beach Horry County',
#  'Lake Worth Inlet/West Palm Beach Palm Beach County',
#  'Kieta',
#  'Navua',
#  'West Beach Galveston',
#  'Off San Pedro Los Angeles County',
#  'Ipswich',
#  'Ambatolaoka Nosy Be Island',
#  'Pina',
#  'Near Brisbane',
#  'North of Jupiter Inlet Palm Beach County',
#  "Rocky Point north shore of O'ahu",
#  '3 miles east of Jacksonville Beach Duval County',
#  'Hamelin Harbour at Faure Island',
#  'Boynton Beach Palm Beach County',
#  'S„o Vicente',
#  'Sodwana',
#  'Beespens False Bay',
#  'Lipson Cove Tumby Bay',
#  'Bathurst Reef Rottnest Island',
#  'Keiskamma River mouth',
#  'Low Island Manus',
#  'Between  Makena & Molokini Maui',
#  'Larnaca',
#  'Off Mooloolabah',
#  'Chennai (formerly Madras',
#  'Maalaea South Maui',
#  'Chennai',
#  'Port Isabela de Basilan',
#  'Off Tower Hill',
#  'Velzyland',
#  'Strand Beach Kissing Point Townsville',
#  'Clovely Beach',
#  'Kerosene Bay',
#  'Leeward side of island directly in back of Mid-Pac barrel storage area',
#  'Kailua Bay',
#  'Off Blau Costa Verde resort',
#  'Jacksonville Duval County',
#  '1.5 miles off Surfside',
#  'Lady Beach at Warrnambool',
#  'Genova S. Nazaro Punta Vagno',
#  'Naghir Island',
#  'Santa Cruz',
#  'Sebastian Inlet Indian River or Brevard County',
#  'Woodman Point',
#  'Geraldton',
#  'Punam Passage Rataman census div Namatanai',
#  'Wallis Island',
#  'Frankston',
#  'Litchfield Beach Georgetown County',
#  'Mahattan',
#  'Coffee Head',
#  'Agulhas Banks',
#  'Guadalupe Island',
#  'Apia Harbor',
#  'Point Halsey Wellington',
#  'Charleston',
#  'Dania Broward County',
#  'Thursday Island',
#  "Maile Point O'ahu",
#  'Abadan',
#  "Kekaha Beach Kaua'i",
#  'Jeffreyís Bay',
#  'Rock Harbor Key Largo Monroe County',
#  'Fish Hoek False Bay',
#  'Airplane Beach Lahina West Maui',
#  'Scarborough Beach Perth',
#  'Trinidad State Beach Humboldt County',
#  'Near Calcutta',
#  'Bunker Bay',
#  'Singatoka River',
#  'Gulf of Mannar',
#  'Vase found during excavations at Lacco Ameno Ischia',
#  'Lauderdale-By-The-Sea Broward County',
#  'Hus Island',
#  'Nuevitas Harbor',
#  'Susak (Rijeka Istria',
#  'Gulf of Mexico 22 miles from Pensacola',
#  'Hawkes Bay',
#  'Macassar',
#  'Long Island',
#  'Trinity Beach Cairns',
#  'Public Beach Siesta Key Sarasota County',
#  '150 miles from Crystal River',
#  'Spot de la gare',
#  'Playa La CabaÒa',
#  'Mouth of Devi River at Machgaon',
#  'Frikkies Bay',
#  'Coronado Strand San Diego County',
#  '3 miles out to sea off Glenelg',
#  'Texas City Galveston',
#  'Hapuna Beach',
#  'Oak Beach',
#  'Egg Rock Middle Harbor Sydney',
#  'Casino Beach Pensacola Escambia County',
#  'Hawkesbury Bridge Sydney',
#  'Bill Baggs Cape Florida State Recreation Area Miami-Dade County',
#  'Macleay River',
#  'Pismo Beach San Luis  Obispo County',
#  'Wabasso Beach Indian River County',
#  'Off Longport Atlantic County',
#  'Belle-Mare',
#  'Near Badu Island',
#  'Hutchinson Island St. Lucie County',
#  'Christchurch',
#  'Fullerís Bay',
#  "Awili South Kona Hawai'i",
#  'Sardinia Bay near Port Elizabeth',
#  'Umgeni River Mouth',
#  'Warra Beach Coral Bay',
#  'Trial Bay north of Kempsey',
#  'Cape Finisterre',
#  'Cape Henlopen State Park Sussex County',
#  'South Beach Hunting Island State Park Beaufort County',
#  '?nciralti Beach ?zmir',
#  'North Bondi',
#  'Off Panama City',
#  'Keratsini',
#  'Backbeach Halls Head',
#  'Chowder Bay Sydney',
#  'Peace Cottage Umdhloti',
#  'Cape Point',
#  '30 miles south of Lynn',
#  'Kirra',
#  'Dodecanese Islands',
#  'Maroubra',
#  'Mpekeweni',
#  'Honeymoon Island near Hopetown',
#  'Pioneer River near Mackay',
#  'Barachoise bridge',
#  'Balmain Sydney (Estuary',
#  'Lovers Key State Park Bonita Springs Lee County',
#  'Poe Beach',
#  'Lanikai Beach Kailua Oahu',
#  'Truk Lagoon',
#  'Bullís Bay near Charleston',
#  'Bethel Shoals Indian River County',
#  'In a canal 10 miles north of St Augustine',
#  'Coal wharf Port Royal',
#  'Volupai Talasea',
#  'Snapper Point Aldinga Beach Adelaide',
#  'Oak Island Brunswick County',
#  'Paradise Beach Jeffreyís Bay',
#  'El Panul 12km south of Coquimbo',
#  'Mount Martha Beach',
#  'la Pointe-au-Sel',
#  'Candeias',
#  'Sandy Hook Bay Highlands Monmouth County',
#  '2 miles off Jupiter Palm Beach County',
#  'Thistle Island',
#  '30 miles from Port Moresby',
#  "Fishman's Island (near Port Moresby PNG",
#  'Oomura Bay',
#  'Cape St. Francis',
#  'Mazlatan',
#  'Lower Delaware Bay',
#  'A ford known as Brodies Coffin in St. Lucia Bay',
#  'A village  north of San Carlos',
#  'Nerang River',
#  'Near Panama City Bay County',
#  '5 miles south of Palm Beach',
#  'Middle Garden Sharm el-Shiekh',
#  'off Paoay Ilocos Norte Province',
#  "Mokapu Kane'ohe Marine Air Corps Station O'ahu",
#  'Sugarloaf Bay Middle Harbor Sydney',
#  'Off Ocean City Cape May County',
#  'Cat Island',
#  'Pointe au Sel',
#  'Manresa State Beach Santa Cruz County',
#  'Ganges Delta',
#  'Waddell Reef Santa Cruz County',
#  '20 miles from Havana',
#  'Off Broughton Island near Port Stephens',
#  'Slipper Island Coromandel Peninsula',
#  'Off Achutuppu Island near Ailigandi',
#  'Chatham Island',
#  'Outer Harbor',
#  'Talkknefiord',
#  'Pointe du Diable',
#  'Sunny Cove Fish Hoek',
#  'Kiddís Beach',
#  '3 km west of Rottnest Island',
#  'Kalk Bay',
#  'Haumoana',
#  'Off Surf City Pender County',
#  'Keawekapu Beach Kihei Maui',
#  'Copacabana Beach Acapulco',
#  'Ellis Beach 20 miles from Cairns',
#  '8 miles off Newport Beach Orange County',
#  'Coney Island',
#  'Seven Mile Beach Gerroa',
#  'Elizabeth City Pasquotank County ',
#  'Mabiuag',
#  'Klamath River Del Norte County',
#  'Aptos Santa Cruz County',
#  '200 miles Leyte',
#  'Ocracoke Inlet Carteret County',
#  'Off Santiago de Cuba',
#  'Leftovers Oahu',
#  'Hokai Malakula',
#  'East side of Bench Island in the Foveaux Strait',
#  'Myrtle Beach Horry County',
#  'Redgate Beach',
#  "1 km off Black's Beach",
#  'Pelican Island Macleay River',
#  'Florida Strait',
#  'Kaikoura',
#  "Honomu Hawai'i",
#  'Fishery Bay',
#  'Simons Town',
#  'Hollywood Beach just above Mattapoisett Harbor Buzzards Bay',
#  'Paradise Bay (next to Wailua Bay Maui',
#  'Folly Beach',
#  'Two Mile Reef Sodwana Bay',
#  'Fiume',
#  'Whiritoa Eastern Cormandel',
#  'Goulburn Island',
#  'Sandy Beach Oahu',
#  'Mzimvubu River',
#  'North Pass Fakarava',
#  'Oak Beach Fire Inlet',
#  'South Beach Fort Pierce St Lucie County',
#  'Tiahura Lagoon',
#  'Muriwai',
#  'Shipwreck Cove Melbourne Aquarium',
#  'The lagoon at Dahab',
#  'Between Keawakapu & Makena Maui',
#  'Cape LevÍque',
#  'New Smyrna Beach / Waveland Volusia County',
#  'Jupiter Beach Palm Beach County',
#  'Hesamabad area of Shushtar 420 km from the sea',
#  'Kokstad District',
#  'Whale Beach',
#  'Cockle Bay Sydney Harbour',
#  'Tamatave',
#  'Boa Viagem Recife',
#  'Tauranga',
#  'Flinders Island',
#  'Sands Cut Elliot Key',
#  '20 miles off Sydney',
#  "Hapuna Beach Hawai'i",
#  'Gracetown',
#  'Playa Linda',
#  'Pacific Beach Grays Harbor County',
#  'Raritan Bay',
#  '204s San Clemente Orange County',
#  'Makenat Maui',
#  'Madang',
#  'Palm Island',
#  '6 km off Collendina south of Melbourne',
#  'Broad Beach Malibu Los Angeles County',
#  'Battle of Guadalcanal',
#  '24 km off Santa Catalina Island in the Channel Islands',
#  'Rockaway',
#  'North Beach St. Augustine',
#  'Riviera Beach near Palm Beach Inlet Palm Beach County',
#  '18 miles south of Port Augusta',
#  'Hobe Sound Beach Palm Beach County',
#  'Shatt-al-Arab River near Abu al Khasib',
#  'Matagorda Beach',
#  'Near Asbestos Works Camellia Parramatta River',
#  'Darnley Island Torres Strait',
#  'Horn Island near Thursday Island',
#  '2 kilometres off Sagay',
#  'Valencia',
#  'Rothesay Bay',
#  'A quarter mile north of Fort Pierce Inlet',
#  "Ewa O'ahu",
#  "Waiokapua Bay/Majors Bay Brennecke Beach Poipu Kaua'i Island",
#  'Ocracoke',
#  'Between Manhattan and The Bronx',
#  'Off the south Devon coast',
#  'Anastasia Island',
#  'Mollymook Beach Bannister Head',
#  'Trincomalee',
#  'Ocean Isle Brunswick County',
#  'Port Newby',
#  "Silver (Silva Channels Waialua O'ahu",
#  'North of Morro Rock San Luis Obispo County',
#  'Clark Island Sydney Harbour',
#  'North Point Beach Moreton Island',
#  'Moffat Beach Caloundra',
#  'Balade',
#  'Kaula Rock near Niihau',
#  'Municipal Bathing area Riviera Beach Palm Beach County',
#  'Durban Bay',
#  'Bellows Beach near Wailea Point Oíahu',
#  'Malakula',
#  'Ormond Beach Volusia County',
#  'Lake Ponchartain off Southshore Harbor New Orleans',
#  'AhÈ Atoll',
#  'Ocean Reef',
#  'La Playa Hornos (near Acapulco',
#  'Black Point',
#  'Noraville',
#  'Ranon Ambryn',
#  'Baker Beach San Francisco County',
#  'Wallabi Point',
#  'Pukapuka Northern Group',
#  'North Beach Eilat',
#  'Sabara Island Calvados Chain 11.4S 153E',
#  'Sarasota Bay',
#  'Otaki',
#  'South Jetty Port Elizabeth',
#  'Isle de GorÈe',
#  'Gleneden Beach',
#  'Ashar Canal where people wash clothes & kitchen pans',
#  'Koror',
#  'Cape Hatteras',
#  'Greenport Sound Long Island',
#  'Koop Reef Truk (Chuuk',
#  'Her¯y',
#  'Two miles from shore in Tamarind Bay',
#  'Mailu area ',
#  'Neptune Duval County',
#  'Robberg Beach Plettenberg Bay',
#  'Paramatta River (near Sydney',
#  'Possession Island',
#  'Monterey Montery County',
#  'North Jetty Fort Pierce Inlet State Park St. Lucie County',
#  'Enuk Island Kavieng',
#  'Horseshoe Rock Santa Barbara County',
#  'Daytona Beach Shores',
#  'Nuíulua',
#  'Honolua Bay',
#  'Flinders Mornington Penisula',
#  'Miami Dade County',
#  'St Lucie County',
#  'Wiggins Pass Collier County',
#  'Off Central American coast at 8N.79W',
#  'Keurbooms',
#  'Padre Island',
#  'Bondi Sydney',
#  'Wreck Point Abrolhos Islands',
#  'Buffalo Bay near Knysna',
#  "Running Waters Beach Ninini Point Kaua'i",
#  'Bound from Cape Town for St. Helena',
#  'Mystic River',
#  'Puente Mayorga San Roque C·diz',
#  'Rockport',
#  'Windy Hill Beach',
#  'Dana Point San Clemente Orange County',
#  'Surf Beach Lompoc Santa Barbara County',
#  'Bolivar Peninsula',
#  'Uilenkraalsmond (near Gansbaai',
#  'In kelp beds off La Jolla San Diego County',
#  'Inyoni Rocks Amanzimtoti',
#  'Charleston Harbor Charleston County',
#  'Kucukada Island',
#  'Danger Reef',
#  '10 miles off Santa Barbara Santa Barbara County',
#  'Langebaan',
#  'Mouth of Langoyan River Davao City',
#  'Itamarac·',
#  'Brunswick Heads',
#  'Bristol Harbor',
#  'Sharm-el-Sheikh',
#  'Bean Hollow State Beach San Mateo County',
#  'Struis Bay',
#  'Colombo Harbor',
#  'Buxton Beach Dare County',
#  'Murray Bay Robben Island',
#  'Fantome Island',
#  'Cartegena',
#  'Playa del Barco La Pedrera',
#  'Trigg Beach',
#  'Ocean Beach San Francisco San Francisco County',
#  'Key West Monroe County',
#  'Cable Beach',
#  'Sebastian Inlet',
#  'Garden Island Sydney',
#  'Hoogly River',
#  'Lost Tree Village Palm Beach County',
#  'Port Aransas',
#  'Half Tide Beach Evans Head',
#  'Mona Passage',
#  'Hooghly River mouth',
#  'Kalepolepo Kihei Maui',
#  'Guadalquivir River',
#  'Muizenberg False Bay',
#  'Bellingen',
#  'Paraiba',
#  'Galveston Ship Channel',
#  'In front of Key Biscayne Beach Club Key Biscayne',
#  'Neptune Beach Duval County',
#  'Fripp Island',
#  '3.2 km inland',
#  'Queensberry Bay',
#  'Off Gun Cay',
#  'Spanish House Beach Brevard County',
#  'Lelepa Island',
#  "St. Augustine Beach St. John's County",
#  'Holden Beach. Brunswick County',
#  'Vera Cruz Harbor',
#  'Off the Battery',
#  'Fairy Bower',
#  'Off Surfside',
#  'Davenport Landing Santa Cruz County',
#  'Bourail',
#  'Pawleyís Island north of Charleston',
#  'North Avoca Beach',
#  'Wedge Island',
#  'Atlantic near New Bern Craven County',
#  'Fig Tree Bridge Lane Cove River near Sydney',
#  'Bastendorf Beach Coos County',
#  'Shrewsbury River  Monmouth County',
#  'Fripp Island Beaufort County',
#  'Near Shelburne Bay Queenland',
#  'Point Henry',
#  'Lambeth Street Wharf Georgeís River East Hills (20 miles from river mouth',
#  'Off Rossel Island Louisiade Archipelago',
#  'Battery Beach Durban',
#  'Palm Beach Palm Beach County',
#  'Near Port Arthur',
#  'Off Vilanculo',
#  'Cabramatta Creek Georgeís River',
#  'Hillsborough Bay',
#  'Western Province',
#  'Kaipara',
#  'Bonny River',
#  'St. Ives',
#  'Toro Passage',
#  'Bakar',
#  'Clarence Heads',
#  'Vetchís Pier Durban',
#  'Siesta Key Sarasota County',
#  'North Dade- Interama area of Biscayne Bay',
#  'James Island Sound Charleston',
#  'Fowey Rock Light Miami',
#  'Anglesea',
#  '3 km off Port Victoria Yorke Peninsula',
#  'Beach Haven Ocean County',
#  'Ramshorn Creek',
#  'Boca Raton Palm Beach County',
#  'Saxon Reef',
#  'Hamstead Pender County',
#  'between Filfla Island and Wied iz-Zurrieq',
#  'Staten Island Richmond County',
#  'Onboard tuna boat M.V. Toscui Maru',
#  'Santa Maria Island Manatee County',
#  'North of Grand Cay',
#  'Off Royal Residence',
#  'Cape Moreton',
#  'Between St. Stjepan and Budva',
#  'Revillagigedo Islands',
#  'Branford New Haven County',
#  'Woodcliff Channel Freeport Long Island',
#  'Long Reef Collaroy',
#  'Bremer Island',
#  'Alma Bay Magnetic Island Townsville',
#  'Point Cook Port Phillip Bay',
#  'Bondoc Peninsula',
#  'Sai Kung Beach',
#  'Madras',
#  'Usal Creek Bear Harbor Mendocino County',
#  'Powell Cay',
#  "D'Entrecasteaux islands 20 miles off the coast",
#  'Ocean City (offshore',
#  'North of Point Sur Monterey County',
#  'Bells Beach',
#  'Cheju Island',
#  'Medola',
#  'Crewing on  the tuna clipper Mary Barbara',
#  'Trial Bay',
#  'Sharm el-Sheikh',
#  'Ano Nuevo San Mateo County',
#  'Lake Pontchartrain',
#  'Gulf Islands National Seashore',
#  'Mudjin Harbor',
#  'Near tuna cannery in Pago Pago Harbor',
#  'Where Colorado River enters the sea',
#  "l'Anse-Vata",
#  'Pulsano near Taranto',
#  "Mana Kaua'i",
#  "Wilson's Promontory Waratah Bay",
#  'North Narrabeen Beach',
#  '20 k off The Spit off the Gold Coast',
#  'Off Duba',
#  'Westbrook Beach',
#  'Havana Harbor',
#  'Sandridge Beach Virginia Beach Princess Anne County',
#  'Œle de Casey',
#  'Southern part',
#  'Cristobal',
#  'Moonee Beach',
#  'Between Dee Why and Long Reef',
#  'Bushy Ilet',
#  '35 miles off Fujairah',
#  'Santa Catalina Island Los Angeles County',
#  'North end of Morris Island at mouth of Charleston Harbor',
#  'Carnac Island',
#  'Bridgetown',
#  'Grand Cay',
#  'Waiapu River mouth  East Cape',
#  'Aniwa Island',
#  "22∫08'S  : 178∫06'W",
#  'Off Fort Pierce St. Lucie County',
#  'Jensen Beach Park Martin County',
#  'Swartklip',
#  'Mordialloc',
#  'Gadsden Point Tampa Bay',
#  'Behune Beach Volusia County',
#  'Nettley Bay',
#  'Sailor Bay Middle Harbour Sydney',
#  'Leichardt Sydney',
#  'St. Croix Cane Bay',
#  'Guantanamo',
#  'Coral Cove Cabo de Santo Agostinho',
#  'North Jetty Park Fort Pierce St Lucie County',
#  'Everglades National Park Monroe County',
#  'Binningup',
#  'Shark tank at Oceanographic Research Insitute Durban',
#  'Scotburgh',
#  'Kouare',
#  'Off Port Alfred',
#  'Lennox Head',
#  'T.O. Strand',
#  'Aigua Blava',
#  "100 miles off Ocean City Maryland in 7000' of water",
#  'Broomfield Reef',
#  'Bramble Reef',
#  '60 miles offshore',
#  "La'aloa Beach Park",
#  'Hutchinson Island',
#  'Andros Island',
#  'Klamath River mouth Del Norte County',
#  'Pula',
#  'North Beach',
#  "Hale'iwa O'ahu",
#  'Surf City',
#  'Winterhaven Park           Ponce Inlet Volusia County',
#  'Peacock Point Balmain Sydney',
#  'San Juan de la Rambla Tenerife',
#  'White Plains Beach Oahu',
#  'KÈrkira',
#  "Jeffrey's Bay",
#  'Pet Den Satellite Beach Brevard County',
#  'Cape Canaveral Brevard County',
#  'Collaroy',
#  "Marciana Marina Isola d'Elba",
#  'Badalona',
#  'Maryborough',
#  'Off Lahaina Maui',
#  'Sidny Ali',
#  'Arroyo Beach Mogadishu',
#  ...}

# %%
#limpieza col Activity
shark_clean.Activity.isnull().sum()
shark_clean.Activity.fillna('UNKNOWN', inplace=True)

def cleaning (text):
    if "SWIMMING" in text:
        s = "SWIMMING"
    elif "FISHING" in text:
        s = "FISHING"
    elif "DIVING" in text:
        s = "DIVING"
    elif "SURF" or "SURFING" in text:
        s = "SURFING"
    else:
        s = text
    return s
shark_clean.Activity=shark_clean.Activity.str.upper()
shark_clean.Activity=shark_clean.Activity.apply(cleaning)


display(shark_clean.Activity.value_counts())
# Out:
# SURFING     3297
# FISHING     1122
# SWIMMING    1063
# DIVING       510
# Name: Activity, dtype: int64

# %%
#limpieza col Name
shark_clean.Name.isnull().sum()
shark_clean.Name.fillna('UNKNOWN', inplace=True)
patternN= ("\s$|^\s|'|\d+")

def supN(te):
    r=re.sub(patternN,"",te)
    return r
shark_clean.Name=shark_clean.Name.apply(supN)

def cleaningN(text):
    if "UNKNOWN" in text:
        s = "UNKNOWN"
    else:
        s = text
    return s
        
shark_clean.Name=shark_clean.Name.apply(cleaningN)
shark_clean.Name=shark_clean.Name.str.replace('male',"UNKNOWN").str.replace("males","UNKNOWN").str.replace('Anonymous',"UNKNOWN").str.replace("girl","UNKNOWN")
shark_clean.Name=shark_clean.Name.str.replace('boat',"UNKNOWN").str.replace("boy","UNKNOWN").str.replace('sailor',"UNKNOWN").str.replace("fishermen","UNKNOWN")
display(set(shark_clean.Name))
display(shark_clean.Name.value_counts())
# Out:
# {'Christian Sanhueza',
#  'Fernando Licay',
#  'John Minard',
#  'Donald Griffin',
#  'Nedugattan',
#  'UNKNOWN Live N Hope',
#  'Joseph Coursey',
#  'Raoul Gillies',
#  'Dunham Coxetter',
#  'Enrico & Noce',
#  'Don Berry',
#  'Boat: occupants: Matt Mitchell &  other people',
#  'Alan Banner,  Peace Corps volunteer',
#  'Noel Feustel',
#  'Price Taylor',
#  'W. Svendson, shipís officer',
#  'Lo-Ying-Chun',
#  'Stephen Flowers',
#  'Hendrie Nkwazi',
#  'Marian Leaf',
#  'Lucas Ransom',
#  'Jack LoMedico',
#  'Jason Williams',
#  'Patrick Imhof',
#  'Tera Tetapana',
#  '"Old Cuba"',
#  'Callie Van Aswegan',
#  'Bruna Silva Gobbi',
#  'Occupants: Hamza Humaid Al Sahraía &  crew',
#  'Mitchell',
#  'Mick Fanning',
#  'Jeff White',
#  'Dave Coulter',
#  'Miriam Picklesimer',
#  'M.G.',
#  'A. Steinstecke',
#  'Dennis Vorster',
#  'Manduray, a lifesaver',
#  'David Adams',
#  'Alistair Kerr',
#  'occupant: child',
#  'Jill Kruse',
#  'John Cooper',
#  'Eloise Tavares',
#  'David Silva',
#  'Mr. Walsh',
#  'Savenaca Kuruvakarua',
#  'Bj¯rn Jensen',
#  'Lowell Lutz',
#  'Robert Stein',
#  'Teresa Holloway',
#  'Stephen Drosdick',
#  'Frederick Dullroy',
#  ' m skiUNKNOWN; Stephanie',
#  'Tony Moolman and another surfer',
#  'Kevin Paffrath',
#  'Alex Reeber',
#  'Albino Ernesto',
#  'Dawood Pili',
#  'Laurie Ross',
#  'M. Filipe',
#  'David Villegas Mora',
#  'Julie Menke',
#  'Arthur Wright',
#  'Steven Harcourt-Wood',
#  'Thomas (or Tony) Madison',
#  'Andrei Johann',
#  'Stan Wing',
#  'Jorge Fernandez',
#  'David Anderson',
#  'Hyoyu Kadena',
#  'Richard Peter Bisley',
#  'Sam Myer',
#  'Aboriginal feUNKNOWN',
#  'Marsh',
#  'Andrew Morris',
#  'Peck Euwer',
#  'Richard Guy',
#  'Alessandro Gomes de Souza',
#  'Bernard Gill',
#  'Gerald Arthur Edwin Denny',
#  'Pasinganlas',
#  'Abraham Johnson',
#  'a young man',
#  'Occupants of skin UNKNOWNs',
#  'Victor Matheson',
#  'William F. Fey',
#  'Bayden Schumann',
#  'John Butcher',
#  'unknown',
#  'Andrew Haas',
#  'David Cook',
#  'Psarofa-gomenes',
#  'David Hunt',
#  'Alton Curtis',
#  ' Czech tourists',
#  'trawler Jacoba, occupant Jan van der Bent',
#  'Remo Adriani',
#  'Valentine Sichter',
#  'French woman',
#  'Kangaroo',
#  'George Facey',
#  'Roger B. Garletts',
#  'Coen Marais',
#  'Felix Brem',
#  'crayfish UNKNOWN. Occupants: Dave & Mitchell Duperouzel:',
#  'Andrew Cribb',
#  'Roy T. Tanaka',
#  'Walmir Pereira da Silva',
#  'Anthony Carter',
#  '-m runabout. Occupant: Allen Gade',
#  'Justin James',
#  'Albertus, a Malay',
#  'Mary Pound',
#  'Joey Nocchi',
#  'E.H. Almond, US Navy radioman',
#  'Matt Mason',
#  'William (or Richard) Schwall',
#  'Brian Henderson',
#  ' hp Boston Whaler UNKNOWN, occupant: G. W. Bane, Jr.',
#  'UNKNOWN Swift, occupants: Dolly Samuels &  other men',
#  'Hamed Salah',
#  'Fishermen',
#  'Charles Anderson',
#  'Thomas Cooke',
#  'Sean Grenfell',
#  'Ranji Lal',
#  'Kyle Kirkpatrick',
#  'Eric Aubrey',
#  'Simon Hammerton',
#  'Felipe Tavares Marinho',
#  'Sue Ferguson',
#  'Rueben',
#  'Greg Filtzer',
#  'Damien Johnson',
#  'Steven Cross',
#  'Joe Davis',
#  'J.L.',
#  ' UNKNOWN, occupants: Ray Peckham, L.C. Wells',
#  'Omar Abdel Qader',
#  'Janet Ferguson',
#  'Rylie Williams',
#  'Tripp Choate',
#  ' pleasure UNKNOWN',
#  'Master of the Errol',
#  'Rouee Youma',
#  'Frank Paxman',
#  'Daniel Macatee',
#  'Bob Smith',
#  'Caterina Gennaro',
#  'Jason King',
#  'Dante Matacchione',
#  'Charles Hutson',
#  'Scott Johnson',
#  'David Zarnowski',
#  'Catherine Delneo',
#  'Burgert Van Der Westhuizen',
#  'Juan de la Cruz Silva Martinez',
#  'Mr. W. H. Hutcheson',
#  'UNKNOWN, a cook',
#  'Lyudmila Stolyarova',
#  'Jenna James',
#  'Neil Buckley',
#  'Cole Taschman',
#  'Peter Clark',
#  'Narcisco Tomaz',
#  'Jean-Pierre Castellani',
#  'Chandler Wynn',
#  'Kiaploki, a UNKNOWN',
#  'Simon Kilaleg',
#  'K. Tracy',
#  'Gary Lieberman',
#  'Sasti',
#  'Fay Jones Bester',
#  'a diver from Kalymnos',
#  'Sarah Whiley',
#  'Sean Mitchley',
#  'Tracy Fasick',
#  'Olivia Hislop',
#  'Charles Blake',
#  'George Jack',
#  'Stephen Davies',
#  'R. Nauth',
#  'Mike deGruy',
#  'David Lonne',
#  'Jai Hennessey',
#  'Daniel MacDonald',
#  'Javier Perez',
#  'Edwin Elford',
#  'Nishi, Japanese diver',
#  'seaman from the York',
#  'Peller Marion',
#  'Ted Nelson  onboard fishing UNKNOWN Wayfarer',
#  'Stanton Waterman',
#  'B.D.',
#  'Row UNKNOWN; occupants -  young men',
#  'Ema Aquilera Prada',
#  'Rolly Lesperance',
#  'Manuel Zamora, a lawyer',
#  'Harvey H. Haley (rescuer)',
#  'Alwin van Breda',
#  'Anthony Zent',
#  'Chip Wagner',
#  'Intriago Diego',
#  'Albert Tyler',
#  'William Carol',
#  'Ron Christmas',
#  'Licius Lee',
#  'Andong &  others',
#  'Brad Milliken',
#  'Percy Wadham',
#  'Joel Bacud',
#  'Conwell Kris',
#  'JosÈ Luiz Lipiani',
#  'John Cibelli',
#  'Murray Branson',
#  'Maika Tabua',
#  'S.D.',
#  'Asena (feUNKNOWN)',
#  'George A. C. Scherer',
#  'Eric Suppeman, cabin UNKNOWN on the Norwegian ship Blanca',
#  'Kenneth Hall',
#  'Motor UNKNOWN, occupants: Quintus Du Toit, J.H. van Heerden & J.P. Marais',
#  'Nathaniel Myrick',
#  'Thomas Cargill',
#  'Stephen Curtis Powell',
#  'Kahlifeh',
#  'US Naval seaman,  one of a crew on a Panama Sea Frontier Naval Patrol craft manned by Coast Guard',
#  'Rodney Baim',
#  'David Kohler',
#  'Because of a mistaken belief that there were no survivors and several other successive errors, of the  to  men who survived the sinking, only  were rescued. Four of the Sullivan brothers died in the initial blast.',
#  'arm recovered from hooked shark',
#  'Mary Katherine Strong',
#  'Ronald Bowers',
#  'Frank Johnson',
#  'Mr. Reynish & Mr. Meikle',
#  ' m skiUNKNOWN',
#  'Keizo Masoyo',
#  'Jennifer Manis',
#  'Ibigan, a Torres Strait islander',
#  'Janie Pelser',
#  'Miss Warren',
#  'Liya Sibili',
#  'Tyler Robertson',
#  'Mark Thompson',
#  'J.J. Dunlap',
#  'Gilbert Dano',
#  'Mr. Perumal',
#  'Norman Clark',
#  'a seaman from the John and Lucy',
#  'Luz Helena  Florez',
#  'Ken Dannewitz',
#  'David Younger, Torres Strait Islander',
#  'Randy Fry',
#  'Andrew Birchall',
#  'Paul Mauger (or Major)',
#  'Roy A. Robinson, Sr.',
#  'Val Valentine',
#  'Wellington dos Santos',
#  'Andre Hartman',
#  'Teta Vaotiare',
#  'a pilot',
#  'UNKNOWN (a whale chaser)',
#  'Matt Searcy',
#  'Andrew Lindop',
#  'Frank Kenny',
#  'Mark Fleming',
#  'Daniel Graham',
#  'Shane Hilder',
#  'Wayne Leong',
#  'Captain Lavarello',
#  'Teresea Britton (on raft) & a man (on floating debris)',
#  'Robert Ford',
#  'Gerald Rauch',
#  'Joe Lawrence',
#  'Patrick Moore',
#  'Joe Hartman',
#  'Warren Johnson',
#  ' m UNKNOWN, occupants John Winslet & customers',
#  'Peter Fraser',
#  'Giorgos',
#  'Leslie Cook',
#  'Bethany Edmund',
#  'Matt Baker',
#  'Mike Sullivan',
#  'Brian Derry, a Naval Rating',
#  'Donald A. Stewart',
#  'ski-UNKNOWN',
#  'Kevin Deacon',
#  'Richard Branson',
#  'Willie van Rensberg',
#  'Douglas Kuchn, Jr.',
#  '-foot cutter',
#  'Ronald Mason',
#  'Andrew Goggin',
#  'a Frenchman',
#  'Dick Lahou',
#  'Tim West',
#  'Brian Anderson',
#  'Pascual Gurran',
#  'Nicolas Virolle',
#  'Hoku Aki',
#  'Dovi',
#  'William Early',
#  'Peter Albury',
#  'Jacob Reitman',
#  'Jose Diaz',
#  'Brian Catarra',
#  'Larry Press',
#  'Alfetto',
#  'Clarence Master',
#  'Tahei Nakatani, a Japanese seaman from the fishing vessel Seiju Maru',
#  'Gerald Soukoff',
#  'Dylan Peyton',
#  'David R. Miles',
#  'Erik Norrie',
#  'Ron Deguilmo',
#  'Eric Vaughters',
#  ' Ethiopian refugees',
#  'Jake Poland',
#  'Lorraine',
#  '. m fibreglass UNKNOWN. Occupant: Jack Siverling',
#  'Aismerael Samsel',
#  'Au Kila (UNKNOWN)',
#  'Akiyoshi Morita',
#  'Samuel, a Thursday islander',
#  'Dennis Washington',
#  'Jana Lutteropp',
#  'Jenny Oliver',
#  'Dr. Michael Hogan',
#  '. m UNKNOWN, occupants:  men',
#  'Jesse Jizdny',
#  'Les Wade',
#  'Christopher Wang',
#  'Josh Green',
#  'Stuart Buchanan',
#  'Fernando Branco de Abreu',
#  'Kim Giambalvo',
#  'Jack Sonter',
#  'Cheyne Kehoe',
#  'Jamie  Harrington',
#  'Rick Neumann',
#  'John Clare',
#  'Salvatore & Agostino Bugeja',
#  'Blake French',
#  'Joe Lees',
#  'John Brothy',
#  'Peter J. White',
#  'Robert Large',
#  'Elizabeth Gardner',
#  'Kelly French',
#  'Michael OBrien',
#  'Simon Parkin',
#  'Whitefield Rolle',
#  'Jonathan Orth',
#  'Elizabeth Schelk',
#  'Charles Blair',
#  'Dr. Weich',
#  'Robert Sato',
#  'David N. Holmgreen',
#  'James Speirs',
#  'Denise Rosemary Burch',
#  'Alan Saffery',
#  'Lungisani Msungubana',
#  'Beverly Comstock',
#  'UNKNOWN, occupant: Portuondo',
#  'Vernon James Berry',
#  'dinghy',
#  'John Peters',
#  'Al Diamond',
#  'Rodney Hughes',
#  'P. Allen',
#  'Benigno Medina Navarrete',
#  'Chaz Cecil',
#  'Dan Argyll',
#  'Martin Lund',
#  'Tony Dicks',
#  '-foot UNKNOWN Sintra',
#  'UNKNOWN, occupants:  UNKNOWN',
#  'Cook',
#  'Tsira Native',
#  'John Bolling',
#  'Kydd Pollock',
#  'Pearl Purdy Scott',
#  'Barbara Green',
#  'C. Thackwray',
#  'Bob Brown',
#  'Nigel Hughes',
#  'John Thompson',
#  'Mary Locklear',
#  'Waade Madigan and Dr Seyong Kim',
#  'Eddy Chaussalet',
#  'Simon Bruce',
#  'Doug Chesser',
#  'The son of Rabbi East',
#  'Henry Jacobson',
#  'Mustafa Al Hammadi',
#  'Joanie Regan',
#  'Mosley',
#  'Stefan Moeller',
#  'Passenger & crew',
#  'A fisherman',
#  'Bob Thompson',
#  'Victor Mooney',
#  'Bob Valentine',
#  'C. Gregory',
#  'Cecil Smith',
#  'Nago, a Japanese diver',
#  'Jarryd Tinson',
#  'a skill. Occupants George Lunsford &  companions',
#  'Odwa Hlanganisela',
#  'Occupants: Scott & John Fulton',
#  'Milton Shane',
#  'Gary Johnson',
#  'Roger Yost',
#  'Erik Lombard',
#  'John Forse',
#  'David Drummond',
#  ' people on ski',
#  'Bernard Venables',
#  'Peter Gerard Spronk',
#  'John Morgan',
#  'Christian Lombard',
#  'William Johnson',
#  'UNKNOWN: occupant, Terry Winters',
#  'Alberto Mayora',
#  ' UNKNOWN. Occupants:  Capt. E.J. Wines, Maj. W. Waller & Larry Waller',
#  'Helmut Scheidl',
#  'soldier, a private',
#  'Matt Kraskiewicz',
#  'Brenda Fried',
#  'a ships steward',
#  'Gesoun Gentel',
#  'P. Kincaid Zifflewwiggett',
#  'Puerto Rican',
#  'a Portuguese soldier',
#  'a young UNKNOWN, one of the crew of the Post Boy',
#  'A. man floating next to Charles G. Heinl',
#  'Chris Humphrey',
#  'Joseph Johnston',
#  ' UNKNOWN,            occupants',
#  'Bernard Wagor',
#  'Ron Kopenski',
#  'Matthew Sonieva',
#  'Barry Neale',
#  'Paolo Stanchi',
#  'Ryan Eckstrum',
#  ' UNKNOWN, occupant:  Richard Wade',
#  'Colin Grant',
#  'Mark Thomas',
#  'Gabriel Botha',
#  'Zacharay Mayo, a U.S. Marine',
#  'Okada',
#  'Don White',
#  'Severed human foot washed ashore (in sneaker with  Velcro closures)',
#  'Joel Healy, Jr.',
#  'Margaret Cruse',
#  'Sherrington',
#  'Bianca Freeman',
#  'Unknown',
#  'small speedUNKNOWN, occupan: Paul McNally',
#  'U. Mataafa',
#  'Mr. Swanson',
#  'Jokin Leizaola',
#  ' cruiser, Maluka II, occupants: Mr & Mrs E. Potts',
#  'Graham Smith',
#  'a deserter from the ship Evarest',
#  'Shawn Carpenter',
#  'Robert Conklin',
#  'Ryla Underwood',
#  'Tim Riley',
#  'Conrad Botha',
#  'Michael Anthony Hoffman',
#  'Douw van der Merwe',
#  'Robert Corowa',
#  'Kelly Getzfread',
#  'Connor Lyon',
#  'Shannon Ainslie',
#  'a Samoan UNKNOWN',
#  'Shannon Lehman',
#  'Aayden Crick',
#  'Clara Alo',
#  'Fishing UNKNOWN',
#  'Chester Kennedy',
#  'Daniel Neumann',
#  'Jorge Alvarez',
#  'UNKNOWN, a US soldier',
#  'Hayward  Green',
#  'Captain Baxter & Dick Chares',
#  'Efrain Ybarra & Francisco Durazzo',
#  'Darryl Kriel',
#  'Greg Long',
#  'Julia Painting',
#  'George Grant',
#  ' stoways',
#  'Thomas Richards',
#  'Ricardo Garcia Santo SÈ†',
#  'Turua William Maretapu',
#  'occupant of a Cessna ',
#  'Jack Smedley',
#  'Leocadio Reyes Sarante',
#  'Louis',
#  'Geovanni Tiago Barbosa',
#  'Aaron Finley',
#  'Chris Massahos',
#  'Leo Vincent  Ryan',
#  'Roniel Jacobs',
#  'Eric Reichardt',
#  'James Elliott',
#  'Marik-Pokas',
#  'Sam Barrows',
#  'Frank Olkulich, the local surf-ski champion',
#  'Dave Manson',
#  'yacht Southerly Buster',
#  'Kairua Gairi',
#  'Aaron Shulman',
#  'Marcus van der Vyver',
#  'Kevin Macghie',
#  'Mr. Barnsfield',
#  'Khodadad, (UNKNOWN)',
#  'Peter S. Ball',
#  'Jeff Weakley',
#  'Marcia Hathaway',
#  'John P.R. Nicholls',
#  'a seaman',
#  'Tyler Cyronak',
#  'Ensign Bromwick',
#  'Ashley Milford',
#  'a pearl diver',
#  'Hamisi Njenga',
#  'Ian James Hill',
#  'Paul Dammann',
#  'Liz Rogers',
#  'Bruce Eldridge',
#  'Keith Davis',
#  'Michaela Grogan',
#  'Peter McCallum',
#  'Nicholas Vossler',
#  'Captain Pattison',
#  'rowUNKNOWN, occupants: Bob Scott & John Blackwell',
#  'Johannes Karl  Schultz',
#  'Bruce Doss',
#  'Bombardier J. Hall, Private Green of the Sherwood Foresters & Captain C. O. Jennings, R.E. Anti-tank Regiment',
#  'Alan Edly Symons',
#  'a old fisherman',
#  'Kath. OíNeill',
#  'Lucas Vertullo',
#  'skiUNKNOWN',
#  'Eichi Nakata, of the the crew of the trawler Kayo Maru',
#  'a refugee',
#  'Ronald R. Powell',
#  'Brian Ware (rescuer)',
#  'Rolf Ridge',
#  ' UNKNOWNs',
#  ' people swimming for shore (pilot &  passengers)',
#  'George Vanderbilt',
#  'Darren Harrity',
#  'UNKNOWN, occupants: P.D. Neilly & Charlton Anderson',
#  'Neil Tapp, cadet lifesaver',
#  'Phillip Flip Steenkamp',
#  'Henri Murray',
#  'David Alexander Manners',
#  'Alan Agnew',
#  'UNKNOWN, a tourist from Germany',
#  'Kevin King',
#  'Most were women & children',
#  'Gordon Harmer',
#  'GÈrald PrÈau',
#  'Giovanni Vuoso',
#  'Charley Smith',
#  'William Cashman',
#  'Kyle K.',
#  'Dr. J. D. Morgan',
#  'Bernard Butch Connor, Jr.',
#  'Ernest Conroy',
#  'Lyle Davis',
#  'Richard Pinder',
#  'E.E., water tender of the U.S.S. Dale',
#  'Nico Abel',
#  'Megan Prescott',
#  'Danny Hoopes',
#  'Ronald J. Bishop',
#  'Daniel Kennedy',
#  'UNKNOWN, Fijian cook of vessel Andi Tui Lomaloma',
#  'Indian people',
#  'Maciello',
#  'Mike Wells',
#  'Ockert Stephanus Heyns',
#  'Frederic Marechal',
#  'Neil Sorenson',
#  'Charles L. Morgan',
#  'Rudolf Daily',
#  'Robert B. Campbell',
#  'Leslie Oswald Harris',
#  'Alfred Haen',
#  'Michael Massey',
#  ' motor launch, occupants: Bill Fulham & T. Fanning',
#  'S. McKie, apprentice st class on the U.S. Naval ship Annapolis',
#  'Paye LeÛn SalomÛn',
#  'Michelle Glenn',
#  'Dakota Hatfield',
#  'a Solomon Islander',
#  'Carolyn Griffin',
#  'Benjamin Rios',
#  'Beth Shannon',
#  'Frank Wacha',
#  'Sylvia Lanner',
#  'G.C.',
#  'Theo Brown',
#  'inflatable dinghy, occupants: Craig Ward & Gavin John Halse',
#  'Tara Dean',
#  'Nil, a dive guide',
#  'Tharsys, a sponge diver',
#  'William Connerly',
#  'Fred Mason',
#  'Armin Trojer',
#  'Peter Dunn',
#  'Pahi',
#  'Linda Ann Norton',
#  'Jonathan Lester',
#  'Jason Coffman',
#  'UNKNOWN, a ship carpenter',
#  'schoolUNKNOWN, a Torres Strait Islander',
#  'Brian Hamilton',
#  'Noel Buxton Redfern',
#  'Nicholas House',
#  'a fisherman / diver',
#  'Gilbert Bui Van Minh',
#  'Mark George',
#  'Robert Sanders',
#  'Boat owned by Ricardo Laneiro',
#  'William C. Lamb',
#  'Bryan Liebetrau',
#  'Johannes Jonk',
#  'JerÙnimo Pereira da Paz',
#  'Jared Voorhees',
#  'Moslem pilgrims',
#  'English UNKNOWN',
#  'Vic Calandra',
#  'Shaka Galera',
#  'Mark Degraff',
#  'Nickerson',
#  'Austin Moore',
#  'Michael Oliver',
#  'Sabit Plana',
#  'Captain Masson',
#  'Paul OLeary',
#  'Ricky Karras, Jr.',
#  'Robin Buckley (UNKNOWN)',
#  'Adolphe Bollander',
#  'Harold Corbett',
#  'Clark Thomas (father / rescuer)',
#  'Occupants: Jack Munro, Quinton Graham & Donald Shadler',
#  'David Bornman',
#  'Etuate Waqa',
#  'E. J. McHugh',
#  'Kila',
#  'Ty Bretz',
#  'John Ogier',
#  'Anthony Joyce',
#  'Lance Cameron',
#  'Curt Vikan',
#  'native UNKNOWN',
#  'A Spanish fisherman',
#  'Lindsay  Munn',
#  'Edwards',
#  'Robert Rogowicz',
#  'John P. Seiner',
#  ' children',
#  'Ayman Abul Hassan',
#  'Elinor Dempsey',
#  'Keith Caruso',
#  'Katrina Tipio',
#  'Jack W. Caldwell',
#  'Gerald Correria',
#  'Jerry Lowney',
#  'Patrick Quinn',
#  'John Benson',
#  'P.L.',
#  'Adeline Lopez',
#  'R. Palmer, shipís apprentice',
#  'D. Smith',
#  'Donald Vaughan',
#  'Mr. Messums servant',
#  'Carla Podzum',
#  ' passengers frightened by shark',
#  'Francisco Pelle',
#  'Edward William Hobbs',
#  'Willie White',
#  'Ken Ahlstrand',
#  'A chiefess',
#  'Diego Gomes Mota',
#  'Japanese feUNKNOWN',
#  'Paul Wilson',
#  'Douglas Lawton',
#  'Donald Fraser Huggins',
#  'Mark Jepson',
#  'Megan Wallis',
#  'a UNKNOWN from Garvakala',
#  'Stephen M¸noz',
#  'Steven Osterman',
#  'Yan Sai-wah',
#  'Gary Jones',
#  'Laurent Manuireva',
#  'Father Jose de Jesus Gomez, a priest',
#  'James Bloodworth, Jr.',
#  'dhow, occupant Eugene Wright',
#  'Jordi Gracia',
#  'Gabriel Fernandez',
#  'Mark Pattison',
#  'Scott Scherger',
#  'Dorothy MacLatchie',
#  'John Regan',
#  'Donald "Harvey" Smith',
#  'Geoffrey Best',
#  'Christian Fairbourne',
#  'Teva Tokoragi',
#  'Andrew Wilson',
#  'Helen Clarke',
#  'Mark Benvick',
#  'Theo Klein',
#  'Sharon Wolfe Cranston',
#  ' poachers',
#  'Jere W. Fountain',
#  'Desmond Chandley',
#  'Mike Porter',
#  'Blair Hall',
#  'Johnny  Bowden',
#  'Mike Duncan',
#  'Benjie Rose',
#  'Michael Valentine',
#  'Ian Barnes',
#  'Nunley',
#  'Tony Donoghue',
#  'Swedish UNKNOWN, crewman from the Harry Mundahl',
#  'John Roult',
#  'Neal Stephenson',
#  'C.K.',
#  'Joseph Blaney',
#  'Laudenilson Gomes de Lima',
#  'adult',
#  'Richard McKenzie',
#  'Geoffrey Walter Black',
#  'Mr. Belle Yang, a school teacher',
#  'Courtney Marcher',
#  'Zane Smith',
#  'Rutu Meli',
#  'Colleen Chamberlin & Scott Chamberlin',
#  'J.M.',
#  'Kris "Cutty" Kildosher',
#  'Garrett Gollihugh',
#  'Luc, a Belgian diver',
#  'William Kennedy',
#  'Joo Whan Hong',
#  'M. Lefevre & a UNKNOWN (rescuer)',
#  ' French divers',
#  'Francisco Edmund Blanc, a scientist from National Museum in Paris',
#  'Boat of Captain Forman White',
#  'catUNKNOWN. Occupants: Captain Tuppe &  young ladiesr',
#  'Cheryl Lowman',
#  'Semesa Vasu',
#  'Robert Lawton (brother & rescuer)',
#  'a father of six',
#  'James Stewart',
#  'Robert Slatzer',
#  'Christopher Holland',
#  'Kenny Burns',
#  'Alcindo de Souza Le„o J˙nior',
#  'Grantley Butcher',
#  'Mark Taylor',
#  'Edward Hayman',
#  'Tran Van Quy',
#  'Mike Shook',
#  'Maurice Bede Philips',
#  'Andrew Smith',
#  'Bruce Bourke',
#  'an Austrian tourist',
#  'Doug Miller',
#  'Nicole Moore',
#  'Gerald Perez',
#  'RowUNKNOWNs, an ocean rowing UNKNOWN. Occupants: Sally Kettle, Claire Mills & Sue McMillan',
#  'Dr. Lucas',
#  'Michael Schaeffer',
#  'Suzanne Pferrer',
#  'Ko Bong-ae (feUNKNOWN)',
#  'Britt Sullivan',
#  'Walter Kefauver',
#  'Adrian Bronson',
#  'John W. Smith',
#  'Hugh Meikel',
#  '. m fibreglass UNKNOWN, occupants: Steven Piggott and Kelvin & Brendan Martin',
#  'Derek Garth Prinsloo',
#  'young aboriginal UNKNOWN',
#  'Josebias Dias',
#  'Gerd Olofsson',
#  ' dinghy,  occupants',
#  'A dinghy',
#  'Eric Rawls',
#  'Ernest Watson',
#  'William McFlood',
#  'Shawn Hamilton',
#  'Alejandro Nodura',
#  'Matthew Robertson Paul',
#  'Sergi Zaloukaev',
#  'Barry Allan Coppin',
#  'UNKNOWN, occupants:  men',
#  'Gilbert S. Hotta',
#  'Fred Hennessee',
#  'Helga Pogl',
#  'Jacque Mostert',
#  'UNKNOWN, occupants:  Mr. Goslin &  passengers',
#  'Thomas Cochrane (William Charles Corkhill',
#  'William Wayne Daniels',
#  'George Carter',
#  'Casey Stewman',
#  'Elke Specker',
#  'Crew of aircraft: McGreevy, Beakley, Rosenthal, Ryan & Hodge',
#  'Kambagil, UNKNOWN',
#  'Jerry',
#  'Cuthbert Vere Lysaght',
#  'Patricia Hodge',
#  'Dick Atkins',
#  'Mervwyn Allum',
#  'Mr. N. Warry',
#  'Trimurti Day',
#  'Mikaela Amezaga Medina',
#  'Jimmy Johnson',
#  'Jellannie Solomon',
#  'Sam Morgan',
#  'Kenny Ruszenas',
#  'Bob Earnhardt',
#  'Mike Barber',
#  ' people were onboard',
#  'Dale Inskeep',
#  'Christine Armstrong',
#  'Carl Derrick Benzoin',
#  'Dave Lowen',
#  'Terrell Moore',
#  'Sek',
#  'Mr. L. E. Brasting',
#  'Kori Robertson',
#  'F.W. Dean',
#  'Robert Walker',
#  'Morgan Flannery',
#  'Michael Casey',
#  'Deno',
#  'Joshua Watson',
#  'Richard Hatch',
#  'Eric Brown',
#  'native diver',
#  'Jaylee Pierce',
#  'Garrett Sebesta',
#  'Dalton Baldwin',
#  'Allan Countryman',
#  'a young Arab',
#  'Jorge Garcia',
#  'Robert Williams',
#  'Gary Hall',
#  'T. Washington',
#  'John Klaso',
#  'Dillon Bowen',
#  'Werner Schonhofer',
#  'Serame "Petrus" Sithole',
#  'Egor Emery',
#  'Alex Lancaster',
#  'Blaise Castellano, Jr.',
#  'Robert Kay',
#  'Patrick  Rooney',
#  'Kirk Koster',
#  'Max Briggs',
#  'All on board perished in the crash',
#  'Rick Carroll',
#  'Bili, a Papuan',
#  'Mr.Johnson (UNKNOWN)',
#  'Morson Daniel',
#  'David Grant',
#  'Mark Meeker',
#  'Kenneth Hiles',
#  'Arthur Cook',
#  'Lindsay Phillips',
#  'Steve Robles',
#  'Ross Menking',
#  'Richard Corrack',
#  'Leo Streng',
#  ' UNKNOWNs, aborigines',
#  'April Dawn  Vogelino',
#  'J. Graden',
#  'Tarara, a UNKNOWN',
#  'Sammy Mira',
#  'R. Vidler',
#  'Dimitris Parassakis',
#  'Mrs. Burman',
#  'William May',
#  'Kenneth William Murray',
#  'Jessica Stephens',
#  'Kosam, a Torres Strait Islander',
#  'a Hungarian refugee',
#  'Yoichi Schamok',
#  'Stuart Rogers',
#  'Joe Thompson',
#  'Chris DeFord',
#  'Lamoman',
#  'David Beaver',
#  'John L. Goodson',
#  'Sage St. Clair',
#  'Pakau',
#  'multiple bathers',
#  'Elison Sevo',
#  'Raymond Senensi',
#  'Manuel Alvelo',
#  'Aaron Seare',
#  'Judson Newton',
#  'Mark Marks',
#  'Roy Pinder',
#  'Jeff Brown',
#  'Josef Slivovic',
#  'Sailor of tuna vessel No. Taiyo Marei',
#  'Jame Crotty',
#  'Gavin Duncan',
#  'Dr. Leonard Read Tibbet',
#  'Norman Whiteley',
#  ' m sportfishing vessel Seabiscuit. Occupants: Captain Louie Abbott &  dozen anglers',
#  'Nguyen Quang Huynh',
#  'Llewellyn Roberts',
#  'Shizuo Nakachi',
#  'Bruce Lucas',
#  'Anand Govindsamy',
#  'Alexis Huesgen',
#  'John Haig',
#  'surf patrol UNKNOWN',
#  'Archie Nottingham',
#  'William Tanner',
#  'Tony Simmonson',
#  'Richard Owen',
#  'Carl Dible',
#  'Isaac OHara,',
#  'Edimilson Henrique dos Santos',
#  'James Tiffee',
#  ' passengers &  crew',
#  'Christiaan Weissig',
#  'Roy Rosser',
#  'Terry Manuel',
#  'Olai',
#  'Janelle Dickinson',
#  'Donald McKenzie',
#  'William Capel',
#  'Andrew Duenas',
#  'Jacques Peens',
#  '"Lockie" Smith',
#  'R. Raymond',
#  'UNKNOWN: Lady Charlotte, occupants: C. McSporran & his crew',
#  'Malay pirates',
#  'UNKNOWN, occupants: Alf Dean, Jack Hood & Otto Bells',
#  'Sean Oliver',
#  'UNKNOWN, occupant Robert Agnew',
#  'Occupants: Andrew & Ben Donegan & Joel Ryan,',
#  'Paul Timothy Lovette, Dr. Neal Beardsley, James C. Russell, Harold H. Mackie, Dale Howard & Diego J. Terres on  Navy craft, Marie',
#  'Abdul Hussain',
#  'Mr. Hill',
#  'Marlene Evler',
#  'Herbert Mills',
#  'Omar Conger',
#  'Brook Watson',
#  'Burke',
#  'Cory Hock',
#  'Alside Raphael Morales Gonzalez',
#  'John Ferrerira',
#  'Mark Wilson',
#  'Geoffrey Kirkam Spence',
#  'Robert Kennedy III',
#  'Barry Kumara',
#  'UNKNOWN Nora, occupant Bruce Harris',
#  'Noah Green',
#  'Chris Ayers',
#  'At least  (and possibly another ) Somali & Ethiopian refugees',
#  'James Cook, a seaman from HMS Comus',
#  'Richard Hegeman',
#  'Vittorio Speca',
#  'Zorca Prinz',
#  'Craig Rogers',
#  'Nahalehau',
#  'Tony Crabtree',
#  'David Pickering',
#  'Roddy Lewis',
#  'Abraham Moreno',
#  'L.G',
#  'David Sparkes',
#  'Roy Inman',
#  'Ashlyn Gilpin',
#  'J.D.',
#  'Inflatable dinghy, occupants: Jasmine Wigley, Greg Wilkie, Phil Rourke & Fleur Anderson',
#  'American aviators',
#  'Dean Brougham',
#  'Robert C. Yeargin',
#  'Valma Tegel',
#  'Erskine H. Reynolds',
#  'Malvis Cristino de Souza',
#  'Dan Prather',
#  'UNKNOWN, occupants; Carl Sjoistrom &  other crew',
#  'Mr. Spain',
#  ...}
# UNKNOWN                                                                   765
# feUNKNOWN                                                                  85
#  UNKNOWNs                                                                  25
# child                                                                      10
# a UNKNOWN                                                                   8
#  UNKNOWN                                                                    7
# UNKNOWNs                                                                    7
# Unidentified                                                                6
# fisherman                                                                   6
# a pearl diver                                                               5
# a native                                                                    5
# black UNKNOWN                                                               4
# Arab UNKNOWN                                                                4
# Unknown                                                                     4
# Zulu UNKNOWN                                                                4
# a soldier                                                                   4
#  men                                                                        4
#  dinghy                                                                     3
# Russian UNKNOWN                                                             3
# aboriginal UNKNOWN                                                          3
# unknown                                                                     3
# UNKNOWN                                                                     3
# dinghy                                                                      3
#  crew                                                                       3
# Andre Hartman                                                               3
# Indian UNKNOWN                                                              3
# American UNKNOWN                                                            3
# Japanese diver                                                              3
# UNKNOWN x                                                                   3
#  women                                                                      3
#                                                                          ...
#  m skiUNKNOWN Graanjan, occupants: Rudy van Graan, Jan de Waal Lombard      1
# L.B.                                                                        1
# Bretton Russell Jones                                                       1
# John Howard                                                                 1
# Shawn Hamilton                                                              1
# Swedish tourist                                                             1
# Johan Deetlefs                                                              1
# flat-bottomed UNKNOWN                                                       1
# feUNKNOWN, an Australian aboriginal                                         1
# Paul Parsons                                                                1
# Frank McDonnell                                                             1
# Kosam, a Torres Strait Islander                                             1
# Andrew Goggin                                                               1
# Sargeant    H.W. Jackson                                                    1
# Peter John Neil                                                             1
# Ray Bennett                                                                 1
# Richard Wands                                                               1
# . m wooden UNKNOWN, occupant: Yoshaiaki Ueda                                1
# H. Cook                                                                     1
# John Leszczak                                                               1
# Colin Grey                                                                  1
# A diver from Spain                                                          1
# a UNKNOWN from Waikato                                                      1
# Scott Armstrong                                                             1
# James Ridley                                                                1
# Julia Painting                                                              1
# Rodigo Cesar                                                                1
# Edward Razzano                                                              1
# " shark attacks in  days"                                                   1
# Ron Dubois                                                                  1
# Name: Name, Length: 4963, dtype: int64

# %%
#limpieza col Sex
shark_clean["Sex "].isnull().sum()
shark_clean["Sex "].fillna('UNKNOWN', inplace=True)
shark_clean["Sex "]=shark_clean["Sex "].str.replace('M ',"M").str.replace("lli","UNKNOWN").str.replace(".","UNKNOWN")

display(shark_clean["Sex "].value_counts())
# Out:
# M          4837
# F           585
# UNKNOWN     569
# N             1
# Name: Sex , dtype: int64

# %%
#limpieza col Injury
shark_clean.Injury.isnull().sum()
shark_clean.Injury.fillna('UNKNOWN', inplace=True)
shark_clean.Injury=shark_clean.Injury.str.upper()
def cleaningI(text):
    if "BITTEN" in text:
        s = "BITTEN"
    elif "FATAL" in text:
        s = "FATAL"
    elif "LACERA"  in text:
        s = "LACERATIONS"
    elif "INJUR" in text:
        s = "INJURY"
    elif "SEVERED" in text:
        s = "SEVERED"
    elif "SURVIVED" in text:
        s = "SURVIVED"
    elif "FOOT" or "LEG" in text:
        s = "DAMANGED LIMD"
    else:
        s = text
    return s

shark_clean.Injury=shark_clean.Injury.str.replace('NO DETAILS',"UNKNOWN")
shark_clean.Injury=shark_clean.Injury.apply(cleaningI)
display(shark_clean.Injury.value_counts())
# Out:
# BITTEN           1529
# LACERATIONS      1218
# FATAL            1091
# INJURY            973
# DAMANGED LIMD     924
# SEVERED           132
# SURVIVED          125
# Name: Injury, dtype: int64

# %%
#limpieza col Age
shark_clean.Age.isnull().sum()
shark_clean.Age.fillna('0', inplace=True)
shark_clean.Age.isnull().sum()
patternA= ("\s$|^\s|'|\D")
patternB= ("^\d{2}")
def supAg(te):
    r=re.sub(patternA,"",te)
    return r



shark_clean.Age=shark_clean.Age.apply(supAg)
#shark_clean.Age=shark_clean.Age.apply(cut)
display(shark_clean.Age.value_counts())
# Out:
# 0           2681
# 17           148
# 18           146
# 20           144
# 19           139
# 15           135
# 16           134
# 21           116
# 22           113
# 24           103
# 25           101
# 14            98
# 13            91
# 30            82
# 23            81
# 26            80
# 27            78
# 28            77
# 29            75
# 12            70
# 32            64
# 35            64
# 40            52
# 10            51
# 31            50
# 38            47
# 34            45
# 43            43
# 33            41
# 36            41
#             ...
# 3626           1
# 1012           1
# 2528           1
# 86             1
# 21342435       1
# 1735           1
# 1822           1
# 2535           1
# 912            1
# 81             1
# 731            1
# 1318           1
# 1820           1
# 2126           1
# 3230           1
# 2826           1
# 1314           1
# 67             1
# 2326           1
# 4634           1
# 1213           1
# 3419           1
# 2320           1
# 910            1
# 3036           1
# 1716           1
# 2              1
# 5030           1
# 73             1
# 72             1
# Name: Age, Length: 115, dtype: int64

# %%
#limpieza col Fatal
shark_clean["Fatal (Y/N)"].isnull().sum()
shark_clean["Fatal (Y/N)"].fillna('UNKNOWN', inplace=True)

patternF= ("\s$|^\s")

def supFF(te):
    r=re.sub(patternF,"",te)
    return r
def cleaningF(text):
    if "#VALUE!" in text:
        s = "UNKNOWN"
    else:
        s = text
    return s
shark_clean["Fatal (Y/N)"]=shark_clean["Fatal (Y/N)"].str.replace('F',"UNKNOWN").str.replace('n',"N")
shark_clean["Fatal (Y/N)"]=shark_clean["Fatal (Y/N)"].apply(supFF)
shark_clean["Fatal (Y/N)"]=shark_clean["Fatal (Y/N)"].apply(cleaningF)
display(shark_clean["Fatal (Y/N)"].value_counts())
# Out:
# N          4325
# Y          1552
# UNKNOWN     115
# Name: Fatal (Y/N), dtype: int64

# %%
#limpieza col Time
shark_clean.Time.isnull().sum()
shark_clean.Time.fillna('UNKNOWN', inplace=True)
shark_clean.Time=shark_clean.Time.str.upper()
def cleaningT(text):
    if "11" in text:
        s = "MORNING"
    elif "10" in text:
        s = "MORNING"
    elif "12" in text:
        s = "MORNING"
    elif "09" in text:
        s = "MORNING"
    elif "08" in text:
        s = "MORNING"
    elif "07" in text:
        s = "MORNING"
    elif "06" in text:
        s = "MORNING"
    elif "13" in text:
        s = "AFTERNOON"
    elif "14" in text:
        s = "AFTERNOON"
    elif "15" in text:
        s = "AFTERNOON"
    elif "16" in text:
        s = "AFTERNOON"
    elif "17" in text:
        s = "AFTERNOON"
    elif "18" in text:
        s = "EVENING"
    elif "19" in text:
        s = "EVENING"
    elif "20" in text:
        s = "EVENING"
    elif "21" in text:
        s = "EVENING"
    elif "22" in text:
        s = "EVENING"
    elif "NIGHT" in text:
        s = "EVENING"
  
    elif "MORN" in text:
        s = "MORNING"
    elif "AFTER" in text:
        s = "AFTERNOON"
    else:
        s = "UNKNOWN"
    return s
shark_clean.Time=shark_clean.Time.apply(cleaningT)
shark_clean.Time.value_counts()
# Out:
# UNKNOWN      3375
# AFTERNOON    1282
# MORNING      1078
# EVENING       257
# Name: Time, dtype: int64

# %%
#limpieza col Investigator or Source
shark_clean["Investigator or Source"].isnull().sum()
shark_clean["Investigator or Source"].fillna('UNKNOWN', inplace=True)
shark_clean["Investigator or Source"]=shark_clean["Investigator or Source"].str.upper()
shark_clean["Investigator or Source"]=shark_clean["Investigator or Source"].str.replace('\d+/\d+/\d+',"")
def cleaningINV(text):
    if "GSAF" in text:
        s = "GSAF"
    elif "FSAF" in text:
        s = "FSAF"
    elif "TIME" in text:
        s = "TIME"
    elif "TIME" in text:
        s = "TIME"
    elif "NBC" in text:
        s = "NBC"
    else:
        s = text
    return s
shark_clean["Investigator or Source"]=shark_clean["Investigator or Source"].apply(cleaningINV)
    
shark_clean["Investigator or Source"].value_counts()
# Out:
# GSAF                                                                                                1106
# TIME                                                                                                 347
# R. COLLIER                                                                                            54
# BRISBANE COURIER,                                                                                     39
# FSAF                                                                                                  27
# SYDNEY MORNING HERALD,                                                                                27
# THE ARGUS,                                                                                            27
# C. MOORE                                                                                              24
# WASHINGTON POST,                                                                                      24
# MIAMI HERALD,                                                                                         24
# ORLANDO SENTINEL,                                                                                     22
# THE AGE,                                                                                              20
# G. VAN GREVELYNGHE                                                                                    19
# CAIRNS POST,                                                                                          19
# THE ADVERTISER,                                                                                       18
# FLORIDA TODAY,                                                                                        17
# JCONLINE                                                                                              16
# UNKNOWN                                                                                               15
# NORTHERN STAR,                                                                                        14
# J. GREEN, P.36                                                                                        14
# W. LEANDER                                                                                            14
# WEST AUSTRALIAN,                                                                                      13
# PALM BEACH POST,                                                                                      12
# THE MERCURY,                                                                                          12
# S. PETERSOHN                                                                                          12
# K. NAKAYA                                                                                             12
# COURIER-MAIL,                                                                                         11
# SYDNEY MORNING HERALD,                                                                                11
# PERTH NOW,                                                                                            11
# C. CRESWELL                                                                                           11
#                                                                                                     ...
# G.P. WHITLEY, P.263; V.M. COPPLESON (1958), P.244                                                      1
# R. & J. ZORRO; NOONSITE.COM                                                                            1
# PORT ADELAIDE FOOTBALL CLUB                                                                            1
# SMCM,                                                                                                  1
# A.M. HODGKIN                                                                                           1
# V.M. COPPLESON (1958), P.266                                                                           1
# BROWNSVILLE HERALD, ; H.D.BALDRIDGE, SAF CASE  #1553                                                   1
# SHARKSURVIVOR.COM; M.I.JOHNSON, DAYTONA BEACH NEWS JOURNAL, , P.1A; DAYTONA NEWS JOURNAL, , P.4B       1
# D. MILLER & R. COLLIER; R. COLLIER, PP.32-33                                                           1
# MOBILE REGISTER ; CHARLOTTE OBSERVER, , P.8A                                                           1
# MALCOLM G. HOOPER; L. SCHULTZ & M. MALIN, P.527                                                        1
# SAIL-WORLD.COM,                                                                                        1
# A.M. RAPSON, P.150; V.M. COPPLESON (1962), P.254                                                       1
# SUNDAY MAIL, , P.1                                                                                     1
# AMARILLO DAILY NEWS,                                                                                   1
# C. LIMBAUGH IN SHARKS & SURVIVAL, PP.77-78                                                             1
# EVENING NEWS (EDINBURGH, SCOTLAND)                                                                     1
# J. MUSICK,                                                                                             1
# A. BRENNEKA, SHARK ATTACK SURVIVORS; THE PALM BEACH POST,                                              1
# BRIDGEPORT POST                                                                                        1
# J. GREEN, P.34                                                                                         1
# V.M. COPPLESON (1958), P.185                                                                           1
# J. BORG, P.68; L. TAYLOR (1993), PP.94-95                                                              1
# S. WYMAN, SUN-SENTINEL, ; LOCAL10.COM                                                                  1
# RANDALL IN SHARKS & SURVIVAL, PP.357                                                                   1
# PARIS NEWS,                                                                                            1
# A. SHARPE, PP.28-32                                                                                    1
# M. MALIN; THE SUN (MELBOURNE),                                                                         1
# D. MILLER & R. COLLIER, V.M. COPPLESON (1958), P.255; R. COLLIER, P. 15                                1
# DR. P. BJOKMAN;  PALM BEACH POST,                                                                      1
# Name: Investigator or Source, Length: 3077, dtype: int64

# %%
#limpieza col pdf
# Out:
# 0         2016.09.18.c-NSB.pdf
# 1     2016.09.18.b-Luciano.pdf
# 2         2016.09.18.a-NSB.pdf
# 3    2016.09.17-Angiolella.pdf
# 4    2016.09.16-BellsBeach.pdf
# 5        2016.09.15.R-boat.pdf
# 6    2016.09.11-PonteVedra.pdf
# 7          2016.09.07-Oahu.pdf
# 8        2016.09.06-Jewell.pdf
# 9    2016.09.05.b-Williams.pdf
# Name: pdf, dtype: object
