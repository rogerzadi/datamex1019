# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import re
import numpy as np

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
url="https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=100&offset=5&sort=sale"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36"}

response = requests.get(url, headers = headers)
results = response.json()
results
flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               brand_name delivery_promises  \
# 0                   Puma                []
# 1                   Vans                []
# 2                   Vans                []
# 3        Nike Sportswear                []
# 4           Jack & Jones                []
# 5            Tommy Jeans                []
# 6         The North Face                []
# 7                Lacoste                []
# 8        Nike Sportswear                []
# 9        Nike Sportswear                []
# 10               Lacoste                []
# 11                Esprit                []
# 12              Converse                []
# 13                  Puma                []
# 14              Superdry                []
# 15          River Island                []
# 16       Nike Sportswear                []
# 17          Lacoste LIVE                []
# 18               Levi's®                []
# 19      adidas Originals                []
# 20           Only & Sons                []
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
total_pages=results['pagination']['page_count']
total_pages
df=pd.DataFrame()
for i in range(total_pages):
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=100&sort=sale'
    
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36"}
    response = requests.get(url, headers = headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
#                        brand_name delivery_promises  \
# sku
# NI112O09A-C11     Nike Sportswear                []
# CO415A00H-909            Converse                []
# A0H12O005-A11               ASICS                []
# PU115B00P-A11                Puma                []
# NI112O08H-A11     Nike Sportswear                []
# C1822D03P-K11  Calvin Klein Jeans                []
# L4722D026-K11        Lacoste LIVE                []
# BRH22O029-G11          Brave Soul                []
# VA215B03L-Q11                Vans                []
# VA222O03F-M11                Vans                []
# CO412A04J-502            Converse                []
# C1812O00X-A11  Calvin Klein Jeans                []
# R0622G01J-K11     Redefined Rebel                []
# LA222P052-A11             Lacoste                []
# NI112O08P-C11     Nike Sportswear                []
# OS322Q095-Q11         Only & Sons                []
# NI112O08W-A13     Nike Sportswear                []
# ...

# %%
# your code 
list(df.brand_name.value_counts().index[0:20])
df.columns
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.replace(",",".").astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5191c8b2a801> in <module>
#       4 #df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
#       5 #df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')
# ----> 6 df['price.promotional']=df['price.promotional'].str.replace(",",".").astype(float)
#       7 type(df['price.promotional'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...

# %%
df['price.promotional'].dtype
df['price.original']=df['price.original'].str.replace(",",".").astype(float)

# %%
df['price.original'].dtype
df['discount_amount']=df['price.original']-df['price.promotional']
df['discount_amount'].head()
# Out:
# <bound method NDFrame.head of sku
# NI112O09A-C11    64.00
# CO415A00H-909    10.50
# A0H12O005-A11    10.50
# PU115B00P-A11    24.00
# NI112O08H-A11    64.00
# C1822D03P-K11    45.00
# L4722D026-K11    31.50
# BRH22O029-G11     7.65
# VA215B03L-Q11     8.00
# VA222O03F-M11     3.00
# CO412A04J-502    13.00
# C1812O00X-A11    49.00
# R0622G01J-K11    19.30
# LA222P052-A11    54.00
# NI112O08P-C11    44.00
# OS322Q095-Q11    15.00
# NI112O08W-A13    30.00
# PI922D01Q-K00     3.00
# TOB22O04X-G11    10.00
# H0422D01V-Q11    15.60
# AD115O0G4-C11    20.00
# NA622T00Z-Q11    40.00
# H0H22O017-Q11     8.80
# AI222D007-K11    60.00
# GLE22S011-C11    30.00
# VA215N005-Q11    16.00
# NI112O0AS-Q11    44.00
# NE215O03F-K11    15.00
# C1822G03Z-Q11    15.00
# AD115O0BO-E11    55.00
#                  ...
# 1FI12O010-A12    33.00
# LE112O02E-A11    18.00
# TP812C022-C11     8.96
# LE222T011-K11    60.00
# GS122S0BC-Q11    24.00
# PI922O0CO-A11     3.75
# NI122S0B8-Q12     9.80
# ...

# %%
df.columns
x= df['discount_amount'].sum() / df['price.original'].sum()
x
# Out:
# 0.2882521617347113
